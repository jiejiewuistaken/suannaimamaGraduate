# %% [markdown]
# # 重构版 - 单品 AAR vs Static（14天）
#
# - S1 综合读入与不确定集构造（单元1-3）
# - S2 仅 Box 集：AAR vs Static 求解、全面评估、可视化（单元4-6）
# - S3 四类不确定集：AAR vs Static 求解、全面评估、可视化（单元7-9）
#
# 说明：本重构段自包含，无需执行旧单元；如需复现实验数据，构造输出 `uncertainty_14d_constructed.csv` 与 `uncertainty_14d_meta.json`。

# %%
# S1-1 依赖与参数
import sys, subprocess, os, glob, re, json, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 依赖
for p in ["openpyxl", "pulp"]:
    try:
        __import__(p)
    except Exception:
        subprocess.check_call([sys.executable, "-m", "pip", "install", p])
import pulp as pl

pd.set_option('display.max_columns', 160)
np.random.seed(42)

# 参数
PRODUCT = "电解镍"
T_days = 14
K_periods = 8

# 成本
h = 1.0
p = 10.0
c = 0.0
f = 100.0
M = 1e6

delta_ratio = 0.2
I1 = 0.0

# 工具：确保成本为实数
def _ensure_real(x, default=0.0):
    try:
        xv = float(x)
        return xv if np.isfinite(xv) else float(default)
    except Exception:
        return float(default)

c = _ensure_real(c, 0.0)
h = _ensure_real(h, 1.0)
p = _ensure_real(p, 10.0)
f = _ensure_real(f, 100.0)
M = _ensure_real(M, 1e6)
print(f"成本参数: c={c}, h={h}, p={p}, f={f}")

# %%
# S1-1b 中文显示与警告抑制（可选）
import matplotlib
from matplotlib import font_manager
import warnings

# 优先使用常见中文字体；若不存在，退回 DejaVu 并关闭缺字警告
preferred_fonts = ['Noto Sans CJK SC', 'SimHei', 'Arial Unicode MS', 'Songti SC', 'PingFang SC']
available = {f.name for f in font_manager.fontManager.ttflist}
fonts = [f for f in preferred_fonts if f in available]
if fonts:
    plt.rcParams['font.sans-serif'] = fonts + ['DejaVu Sans']
else:
    plt.rcParams['font.sans-serif'] = ['DejaVu Sans']
# 解决负号显示
plt.rcParams['axes.unicode_minus'] = False
# 抑制“Glyph missing from font”告警
warnings.filterwarnings('ignore', message='Glyph .* missing from font\(s\) .*', category=UserWarning)

# %%
# S1-2 统一读入与不确定集构造（生成 d_hat, delta, poly_beta_prev, rho, w_eps, w_radius_abs）
# 复用之前合并导入逻辑

# ... 为简洁，这里直接复用已实现的合并导入单元内容 ...
import numpy as np, pandas as pd, os, glob, re, json, warnings

# 从先前单元复制的合并实现（略注释）

def _safe_read_excel(path: str):
    try:
        return pd.read_excel(path)
    except Exception:
        try:
            return pd.read_excel(path, engine='openpyxl')
        except Exception:
            return None

_syn = {
    'xgboost':'XGBoost','lightgbm':'LightGBM','catboost':'CatBoost',
    'randomforest':'RandomForest','random_forest':'RandomForest',
    'linearregression':'LinearRegression','linear':'LinearRegression','ols':'LinearRegression',
    'qrf':'QRF','quantileforest':'QRF','quantilerandomforest':'QRF','svr':'SVR','lstm':'LSTM','best':'Best'
}

def _norm(name: str) -> str:
    key = re.sub(r'[^a-z]', '', str(name).lower())
    return _syn.get(key, name)

def _best_model_from_perf(perf_paths):
    if not perf_paths:
        return None
    dfp = _safe_read_excel(perf_paths[0])
    if not isinstance(dfp, pd.DataFrame) or dfp.empty:
        return None
    model_col = None
    for c in dfp.columns:
        lc = str(c).lower()
        if ('model' in lc) or ('模型' in str(c)):
            model_col = c; break
    if model_col is None:
        model_col = dfp.columns[0]
    def _find(keys):
        keys = [k.lower() for k in keys]
        for c in dfp.columns:
            lc = str(c).lower()
            if any(k in lc for k in keys):
                if 'wmape' in lc and 'mape' in keys:
                    continue
                return c
        return None
    cols = [_find(['mae']), _find(['rmse']), _find(['mape']), _find(['wmape'])]
    cols = [c for c in cols if c is not None]
    if not cols:
        return None
    ranks = dfp[cols].rank(ascending=True, method='average')
    dfp['avg_rank'] = ranks.mean(axis=1)
    best = dfp.sort_values('avg_rank', kind='mergesort').iloc[0]
    return str(best[model_col])

def _avail_prefixes(df: pd.DataFrame):
    return sorted(set(re.sub(r'_prediction$', '', c) for c in df.columns if str(c).endswith('_prediction')))

def _pick_prefix(best_name: str, df: pd.DataFrame):
    prefs = _avail_prefixes(df)
    if not prefs:
        return None
    if best_name:
        nn = _norm(best_name)
        for p in prefs:
            if nn.lower() in p.lower() or p.lower() in nn.lower():
                return p
    for p in ['QRF','XGBoost','LightGBM','RandomForest','LinearRegression','SVR','LSTM','Best']:
        if any(p.lower()==q.lower() for q in prefs):
            return p
    return prefs[0]

files = {
    'detail': sorted(glob.glob('**/*逐日预测详细结果*.xlsx', recursive=True)),
    'weekly': sorted(glob.glob('**/*逐周汇总结果*.xlsx', recursive=True)),
    'perf':   sorted(glob.glob('**/*逐日预测模型性能对比*.xlsx', recursive=True)),
    'csv':    sorted(glob.glob('**/all_future_predictions.csv', recursive=True)),
}

perf_best = _best_model_from_perf(files['perf'])

forecast_df = None
source = None

if files['detail']:
    df = _safe_read_excel(files['detail'][0])
    if isinstance(df, pd.DataFrame) and not df.empty:
        forecast_df = df.copy(); source = 'daily_detail_xlsx'
elif files['weekly']:
    dfw = _safe_read_excel(files['weekly'][0])
    if isinstance(dfw, pd.DataFrame) and not dfw.empty:
        if 'week_start' not in dfw.columns:
            c0 = next((c for c in dfw.columns if 'week' in c.lower() or 'date' in c.lower()), None)
            if c0: dfw.rename(columns={c0:'week_start'}, inplace=True)
        dfw['week_start'] = pd.to_datetime(dfw['week_start'], errors='coerce')
        dfw = dfw.sort_values('week_start').reset_index(drop=True)
        fcols = [c for c in dfw.columns if c.endswith('_forecast')]
        if len(dfw)%2==1: dfw = dfw.iloc[:-1]
        dfw['period'] = (dfw.index // 2) + 1
        long = []
        for c in fcols:
            tmp = dfw[['period', c]].copy()
            pref = c.replace('_forecast','')
            tmp.rename(columns={c: f'{pref}_prediction'}, inplace=True)
            long.append(tmp)
        if long:
            base = long[0][['period']].copy()
            for t in long:
                base = base.merge(t, on='period', how='left')
            base['date'] = pd.to_datetime('2025-01-01') + pd.to_timedelta((base['period']-1)*T_days, unit='D')
            forecast_df = base; source = 'weekly_summary_xlsx'
elif files['csv']:
    try:
        dfc = pd.read_csv(files['csv'][0])
        if {'date','prediction'} <= set(dfc.columns):
            dfc['date'] = pd.to_datetime(dfc['date'], errors='coerce')
            dfc = dfc.sort_values('date')
            dfc['period'] = ((dfc['date'] - dfc['date'].min()).dt.days // T_days) + 1
            agg = dfc.groupby('period', as_index=False)['prediction'].sum()
            forecast_df = agg.rename(columns={'prediction':'Baseline_prediction'})
            forecast_df['date'] = pd.to_datetime('2025-01-01') + pd.to_timedelta((forecast_df['period']-1)*T_days, unit='D')
            source = 'all_future_predictions.csv'
    except Exception:
        pass

if forecast_df is None:
    days = T_days * K_periods
    date_index = pd.date_range(start="2025-01-01", periods=days, freq="D")
    base = 1000
    season = 200*np.sin(np.arange(days)/7*2*np.pi)
    noise = np.random.normal(0, 50, size=days)
    pred = np.maximum(base + season + noise, 100)
    dfc = pd.DataFrame({'date': date_index, 'prediction': pred})
    dfc['period'] = ((dfc['date'] - dfc['date'].min()).dt.days // T_days) + 1
    agg = dfc.groupby('period', as_index=False)['prediction'].sum()
    forecast_df = agg.rename(columns={'prediction':'Baseline_prediction'})
    forecast_df['date'] = pd.to_datetime('2025-01-01') + pd.to_timedelta((forecast_df['period']-1)*T_days, unit='D')
    source = 'synthetic'

if 'date' in forecast_df.columns:
    forecast_df['date'] = pd.to_datetime(forecast_df['date'], errors='coerce')
if 'period' not in forecast_df.columns:
    forecast_df['period'] = ((forecast_df['date'] - forecast_df['date'].min()).dt.days // T_days) + 1

chosen_prefix = _pick_prefix(perf_best, forecast_df)

def _col(prefix: str, suffixes):
    for sfx in suffixes:
        c = f"{prefix}_{sfx}"
        if c in forecast_df.columns:
            return c
    return None

pred_col = _col(chosen_prefix, ['prediction']) or ('Best_prediction' if 'Best_prediction' in forecast_df.columns else None)
lo_col   = _col(chosen_prefix, ['band_lo','ellip_lo_90'])
hi_col   = _col(chosen_prefix, ['band_hi','ellip_hi_90'])
q90_col  = _col(chosen_prefix, ['roll_abs_q90_28d'])
mae_col  = _col(chosen_prefix, ['roll_mae_28d'])
std_col  = _col(chosen_prefix, ['roll_std_28d'])

z90 = 1.645

_df = forecast_df.copy()
_df['_pred'] = pd.to_numeric(_df[pred_col], errors='coerce') if pred_col else np.nan
if lo_col and hi_col:
    _df['_lo'] = pd.to_numeric(_df[lo_col], errors='coerce')
    _df['_hi'] = pd.to_numeric(_df[hi_col], errors='coerce')
else:
    mag = None
    for candi in [q90_col, mae_col, std_col]:
        if candi is None: continue
        v = pd.to_numeric(_df[candi], errors='coerce')
        if candi == std_col:
            v = z90 * v
        mag = v; break
    if mag is None:
        mag = delta_ratio * _df['_pred']
    _df['_lo'] = _df['_pred'] - mag
    _df['_hi'] = _df['_pred'] + mag
_df['_lo'] = _df['_lo'].clip(lower=0)

if std_col:
    _df['_sigma'] = pd.to_numeric(_df[std_col], errors='coerce')
elif q90_col:
    _df['_sigma'] = pd.to_numeric(_df[q90_col], errors='coerce') / z90
elif mae_col:
    _df['_sigma'] = 1.25 * pd.to_numeric(_df[mae_col], errors='coerce')
else:
    _df['_sigma'] = 0.2 * _df['_pred']

if 'W1_radius_best_28d' in _df.columns:
    _df['_w1'] = pd.to_numeric(_df['W1_radius_best_28d'], errors='coerce')
elif q90_col:
    _df['_w1'] = pd.to_numeric(_df[q90_col], errors='coerce')
elif mae_col:
    _df['_w1'] = 1.25 * pd.to_numeric(_df[mae_col], errors='coerce')
else:
    _df['_w1'] = 0.2 * _df['_pred']

agg_pred  = _df.groupby('period')['_pred'].sum()
agg_lo    = _df.groupby('period')['_lo'].sum()
agg_hi    = _df.groupby('period')['_hi'].sum()
agg_sigma = _df.groupby('period')['_sigma'].apply(lambda s: float(np.sqrt(np.nansum(np.square(s.to_numpy())))))
agg_w1    = _df.groupby('period')['_w1'].sum()

d_hat = agg_pred.to_numpy()[:K_periods].astype(float)
box_delta = np.maximum(agg_hi.to_numpy() - agg_pred.to_numpy(), agg_pred.to_numpy() - agg_lo.to_numpy())[:K_periods].astype(float)
delta = box_delta.copy()
K = len(d_hat)
poly_beta_prev = (box_delta[:-1] + box_delta[1:]).astype(float) if K>1 else np.array([], dtype=float)

rho = float(1.645 * np.linalg.norm(agg_sigma.to_numpy()[:K], ord=2))
rho1 = float(np.sqrt(K) * rho)
w_eps = float(np.linalg.norm(agg_w1.to_numpy()[:K], ord=2))
w_radius_abs = float(np.max(agg_w1.to_numpy()[:K]))

out = pd.DataFrame({'period': np.arange(1, K+1), 'd_hat': d_hat, 'box_delta': box_delta})
out['poly_beta_prev'] = pd.Series(poly_beta_prev).reindex(range(K), fill_value=np.nan)
out.to_csv('uncertainty_14d_constructed.csv', index=False)
with open('uncertainty_14d_meta.json','w',encoding='utf-8') as fh:
    json.dump({'source':source,'best':perf_best,'prefix':chosen_prefix,'K':int(K),'rho':rho,'w_eps':w_eps,'w_abs':w_radius_abs}, fh, ensure_ascii=False, indent=2)

print(f"[S1 完成] 源:{source} | 最优:{perf_best}->{chosen_prefix} | K={K} | box比≈{float(np.mean(delta/np.maximum(d_hat,1e-6))):.3f}")

# %%
# S1-3 可选：跨模型离散度微调（调整 delta/poly/rho/w1）
# 可根据需要执行；默认参数见下
adj_models = ['LSTM','QRF','RandomForest']
dispersion_measure = 'range_ratio'  # 'range_ratio' | 'std_ratio'
tau_lo, tau_hi = 0.10, 0.30
gamma_lo, gamma_hi = 0.95, 1.25

def _aggregate_models_period(df: pd.DataFrame, models: list[str]) -> pd.DataFrame:
    need = []
    for m in models:
        col = f"{m}_prediction"
        if col in df.columns:
            need.append(col)
    if not need:
        return pd.DataFrame()
    tmp = df[['period'] + need].copy()
    agg = tmp.groupby('period')[need].sum(min_count=1)
    agg.columns = [c.replace('_prediction','') for c in agg.columns]
    return agg.reset_index()

Gamma = np.ones_like(d_hat, dtype=float)
if isinstance(forecast_df, pd.DataFrame):
    if 'period' not in forecast_df.columns and 'date' in forecast_df.columns:
        forecast_df['period'] = ((pd.to_datetime(forecast_df['date']) - pd.to_datetime(forecast_df['date']).min()).dt.days // T_days) + 1
    agg_tbl = _aggregate_models_period(forecast_df, adj_models)
    if not agg_tbl.empty:
        merged = pd.DataFrame({'period': np.arange(1, len(d_hat)+1), 'd_hat': d_hat}).merge(agg_tbl, on='period', how='left')
        ratios = []
        for _, row in merged.iterrows():
            vals = [row[m] for m in adj_models if m in merged.columns]
            vals = [float(v) for v in vals if pd.notna(v)]
            if len(vals) >= 2:
                if dispersion_measure == 'range_ratio':
                    disp = (max(vals) - min(vals)) / max(float(row['d_hat']), 1e-6)
                else:
                    mu = np.mean(vals); sd = float(np.std(vals)); disp = sd / max(float(row['d_hat']), 1e-6)
            else:
                disp = np.nan
            ratios.append(disp)
        ratios = np.array(ratios, dtype=float)
        for k in range(len(d_hat)):
            r = ratios[k]
            if not np.isfinite(r):
                Gamma[k] = 1.0
            elif r <= tau_lo:
                Gamma[k] = gamma_lo
            elif r >= tau_hi:
                Gamma[k] = gamma_hi
            else:
                t = (r - tau_lo) / (tau_hi - tau_lo)
                Gamma[k] = gamma_lo + t*(gamma_hi - gamma_lo)

# 应用缩放
box_base = delta.copy()
delta = (delta * Gamma).astype(float)
poly_beta_prev = (Gamma[:-1]*box_base[:-1] + Gamma[1:]*box_base[1:]).astype(float) if K>1 else np.array([], dtype=float)

# 近似缩放椭球/W1 半径
gamma_rms = float(np.sqrt(np.mean(np.square(Gamma))))
try:
    rho = float(rho) * gamma_rms
    rho1 = float(np.sqrt(K) * rho)
except Exception:
    pass
try:
    w_eps = float(w_eps) * gamma_rms
    w_radius_abs = float(w_radius_abs) * float(np.max(Gamma))
except Exception:
    pass
print(f"[S1-微调] Gamma范围 {float(Gamma.min()):.3f}~{float(Gamma.max()):.3f}")

# %%
# S2-0 AAR/Static 公共构造（含 poly/ell1/wass 所需函数）

# Poly 对偶上界工具（复用 S1 参数）

def stage_Fg_from_box_and_diff(delta_vec, beta_vec=None):
    K_ = len(delta_vec)
    I = np.eye(K_)
    rows = [ +I, -I ]
    bs = [ delta_vec, delta_vec ]
    if beta_vec is not None and K_ > 1:
        D = np.zeros((K_-1, K_))
        for k in range(1, K_):
            D[k-1, k] = 1; D[k-1, k-1] = -1
        rows.append(+D); bs.append(np.array(beta_vec, dtype=float))
        rows.append(-D); bs.append(np.array(beta_vec, dtype=float))
    F_full = np.vstack(rows)
    g_full = np.concatenate(bs)
    def stage_Fg(k):
        mask = np.max(np.abs(F_full[:, :k]), axis=1) > 0
        return F_full[mask, :k], g_full[mask]
    return stage_Fg

stage_Fg = stage_Fg_from_box_and_diff(delta, poly_beta_prev if len(poly_beta_prev)>0 else None)


def poly_dual_bound(mdl, c_dict, k, prefix):
    Fk, gk = stage_Fg(k)
    lam = pl.LpVariable.dicts(f"lam_{prefix}_k{k}", list(range(Fk.shape[0])), lowBound=0)
    for j in range(k):
        mdl += pl.lpSum(Fk[i, j]*lam[i] for i in range(Fk.shape[0])) == c_dict.get(j+1, 0.0)
    return pl.lpSum(gk[i]*lam[i] for i in range(Fk.shape[0]))

# ell1/wass 线性近似 envelope2

def build_aar_with_envelope2(envelope_type='ell1'):
    assert envelope_type in ('ell1','wass')
    R = float(rho1) if envelope_type == 'ell1' else float(w_radius_abs)
    mdl = pl.LpProblem(f"AAR_{envelope_type}_lin", pl.LpMinimize)
    v_ = pl.LpVariable.dicts('v', list(range(1, K+1)), 0, 1, cat=pl.LpBinary)
    u0_ = pl.LpVariable.dicts('u0', list(range(1, K+1)), lowBound=0)
    A_ = {(k,t): pl.LpVariable(f"a_{k}_{t}", lowBound=None) for k in range(1,K+1) for t in range(1,k)}
    y0_ = pl.LpVariable.dicts('y0', list(range(1, K+1)), lowBound=0)
    Y_ = {(k,t): pl.LpVariable(f"Y_{k}_{t}", lowBound=None) for k in range(1,K+1) for t in range(1,k+1)}
    cumd = np.cumsum(d_hat)

    for k in range(1, K+1):
        if k == 1:
            mdl += u0_[1] >= 0
            mdl += u0_[1] <= M * v_[1]
        else:
            mU = pl.LpVariable(f"mU_{k}", lowBound=0)
            for t in range(1, k):
                mdl +=  mU >=  A_[(k,t)]
                mdl +=  mU >= -A_[(k,t)]
            env = R * mU
            mdl += u0_[k] - env >= 0
            mdl += u0_[k] + env <= M * v_[k]

    for k in range(1, K+1):
        const_k = I1 + pl.lpSum(u0_[i] for i in range(1, k+1)) - float(cumd[k-1])
        coeff = {}
        for t in range(1, k+1):
            coeff[t] = pl.lpSum(A_[(i,t)] for i in range(max(t+1,2), k+1) if (i,t) in A_)
            if t == k:
                coeff[t] = coeff[t] + (-1)
        y_const = y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1, k+1))
        mH = pl.LpVariable(f"mH_{k}", lowBound=0)
        for t in range(1, k+1):
            mdl += mH >=  (Y_[(k,t)] - h*coeff[t])
            mdl += mH >= -(Y_[(k,t)] - h*coeff[t])
        mdl += y_const >= h*const_k + R * mH
        mP = pl.LpVariable(f"mP_{k}", lowBound=0)
        for t in range(1, k+1):
            mdl += mP >=  (-p*coeff[t] - Y_[(k,t)])
            mdl += mP >= -(-p*coeff[t] - Y_[(k,t)])
        mdl += y_const >= p*(-const_k) + R * mP

    mG = pl.LpVariable("mG", lowBound=0)
    for t in range(1, K+1):
        expr = c * pl.lpSum(A_[(i,t)] for i in range(max(t+1,2), K+1) if (i,t) in A_)
        mdl += mG >=  expr
        mdl += mG >= -expr

    W_ = pl.LpVariable('W', lowBound=0)
    mdl += W_ >= pl.lpSum([f*v_[k] + c*u0_[k] + (y0_[k] + pl.lpSum([Y_[(k,t)]*d_hat[t-1] for t in range(1,k+1)])) for k in range(1, K+1)]) + R * mG
    mdl.setObjective(W_)
    return mdl, dict(v=v_, u0=u0_, A=A_, y0=y0_, Y=Y_)

# AAR poly（需要 poly_dual_bound）

def build_aar_with_envelope(envelope_type='poly'):
    assert envelope_type == 'poly'
    mdl = pl.LpProblem("AAR_poly", pl.LpMinimize)
    v_ = pl.LpVariable.dicts('v', list(range(1, K+1)), 0, 1, cat=pl.LpBinary)
    u0_ = pl.LpVariable.dicts('u0', list(range(1, K+1)), lowBound=0)
    A_ = {(k,t): pl.LpVariable(f"a_{k}_{t}", lowBound=None) for k in range(1,K+1) for t in range(1,k)}
    y0_ = pl.LpVariable.dicts('y0', list(range(1, K+1)), lowBound=0)
    Y_ = {(k,t): pl.LpVariable(f"Y_{k}_{t}", lowBound=None) for k in range(1,K+1) for t in range(1,k+1)}
    cumd = np.cumsum(d_hat)

    for k in range(1, K+1):
        if k == 1:
            mdl += u0_[1] >= 0
            mdl += u0_[1] <= M * v_[1]
        else:
            # u 界 poly 对偶
            c_pos = {t: A_[(k,t)] for t in range(1,k)}
            b_pos = poly_dual_bound(mdl, c_pos, k-1, prefix=f"u_pos_k{k}")
            c_neg = {t: -A_[(k,t)] for t in range(1,k)}
            b_neg = poly_dual_bound(mdl, c_neg, k-1, prefix=f"u_neg_k{k}")
            mdl += u0_[k] - b_neg >= 0
            mdl += u0_[k] + b_pos <= M * v_[k]

    for k in range(1, K+1):
        const_k = I1 + pl.lpSum(u0_[i] for i in range(1, k+1)) - float(cumd[k-1])
        coeff = {}
        for t in range(1, k+1):
            coeff[t] = pl.lpSum(A_[(i,t)] for i in range(max(t+1,2), k+1) if (i,t) in A_)
            if t == k:
                coeff[t] = coeff[t] + (-1)
        c1 = {t: (Y_[(k,t)] - h*coeff[t]) for t in range(1,k+1)}
        b1 = poly_dual_bound(mdl, c1, k, prefix=f"yh")
        mdl += (y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1,k+1))) >= h*const_k + b1
        c2 = {t: (-p*coeff[t] - Y_[(k,t)]) for t in range(1,k+1)}
        b2 = poly_dual_bound(mdl, c2, k, prefix=f"yp")
        mdl += (y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1,k+1))) >= p*(-const_k) + b2

    W_ = pl.LpVariable('W', lowBound=0)
    # 目标中的 z 系数上界也用 poly 对偶
    obj_terms = []
    for t in range(1, K+1):
        c_dict = {t: c * pl.lpSum(A_[(i,t)] for i in range(max(t+1,2), K+1) if (i,t) in A_)}
        obj_terms.append(poly_dual_bound(mdl, c_dict, t, prefix=f"obj_t{t}"))
    mdl += W_ >= pl.lpSum([f*v_[k] + c*u0_[k] + (y0_[k] + pl.lpSum([Y_[(k,t)]*d_hat[t-1] for t in range(1,k+1)])) for k in range(1, K+1)]) + pl.lpSum(obj_terms)
    mdl.setObjective(W_)
    return mdl, dict(v=v_, u0=u0_, A=A_, y0=y0_, Y=Y_)

# %%
# S2-1 公共函数（评估/可视化）

def affine_policy_orders(u0_vec, A_mat, z_vec):
    K_ = len(u0_vec)
    u = np.array(u0_vec, dtype=float).copy()
    if A_mat is None:
        return np.maximum(u, 0.0)
    for k in range(1, K_):
        u[k] = u0_vec[k] + float(np.dot(A_mat[k, :k], z_vec[:k]))
    return np.maximum(u, 0.0)


def simulate_trajectory(u_vec, v_vec, d_hat_vec, z_vec, I1_, costs):
    f_, c_, h_, p_ = costs
    K_ = len(u_vec)
    I = np.zeros(K_)
    d_real = d_hat_vec + z_vec
    I[0] = I1_ + u_vec[0] - d_real[0]
    for k in range(1, K_):
        I[k] = I[k-1] + u_vec[k] - d_real[k]
    y_pos = np.maximum(I, 0)
    y_neg = np.maximum(-I, 0)
    fixed = f_ * np.sum((v_vec > 0.5).astype(int))
    variable = c_ * np.sum(u_vec)
    holding = h_ * np.sum(y_pos)
    penalty = p_ * np.sum(y_neg)
    total = fixed + variable + holding + penalty
    service_rate = np.mean(I >= 0)
    stockouts = int(np.sum(I < 0))
    return dict(total=total, fixed=fixed, variable=variable, holding=holding, penalty=penalty,
                service_rate=service_rate, stockouts=stockouts, I_series=I)


def evaluate(u0_vec, A_mat, v_vec, d_hat_vec, delta_vec, I1_, costs, num_mc=300, seed=2025):
    rng = np.random.default_rng(seed)
    z0 = np.zeros_like(delta_vec)
    nom = simulate_trajectory(affine_policy_orders(u0_vec, A_mat, z0), v_vec, d_hat_vec, z0, I1_, costs)
    z_plus = +delta_vec; z_minus = -delta_vec
    plus = simulate_trajectory(affine_policy_orders(u0_vec, A_mat, z_plus), v_vec, d_hat_vec, z_plus, I1_, costs)
    minus = simulate_trajectory(affine_policy_orders(u0_vec, A_mat, z_minus), v_vec, d_hat_vec, z_minus, I1_, costs)
    mc = []
    for _ in range(num_mc):
        z = rng.uniform(low=-delta_vec, high=+delta_vec)
        mc.append(simulate_trajectory(affine_policy_orders(u0_vec, A_mat, z), v_vec, d_hat_vec, z, I1_, costs))
    def agg(key):
        arr = np.array([it[key] for it in mc])
        return dict(mean=float(arr.mean()), std=float(arr.std()), p90=float(np.quantile(arr,0.9)),
                    p95=float(np.quantile(arr,0.95)), p99=float(np.quantile(arr,0.99)))
    totals = np.array([it['total'] for it in mc])
    var95 = float(np.quantile(totals, 0.95))
    cvar95 = float(totals[totals>=var95].mean())
    return dict(nominal=nom, plus=plus, minus=minus,
                mc=dict(total=agg('total'), service=agg('service_rate'), stockouts=agg('stockouts'),
                        VaR95=var95, CVaR95=cvar95))


def plot_distributions(method_records):
    plt.figure(figsize=(11,6))
    for name, totals in method_records.items():
        plt.hist(totals, bins=24, alpha=0.35, density=True, label=name)
        plt.axvline(np.mean(totals), linestyle='--', linewidth=1)
    plt.title('随机场景总成本分布对比')
    plt.xlabel('Total cost'); plt.ylabel('Density'); plt.legend(); plt.show()

# %%
# S2-2 仅 Box 集：构建 AAR 与 Static

# AAR (box)
def build_aar_box():
    mdl = pl.LpProblem("AAR_box", pl.LpMinimize)
    v = pl.LpVariable.dicts('v', list(range(1, K+1)), 0, 1, cat=pl.LpBinary)
    u0 = pl.LpVariable.dicts('u0', list(range(1, K+1)), lowBound=0)
    A = {(k,t): pl.LpVariable(f"a_{k}_{t}", lowBound=None) for k in range(1,K+1) for t in range(1,k)}
    y0 = pl.LpVariable.dicts('y0', list(range(1, K+1)), lowBound=0)
    Y = {(k,t): pl.LpVariable(f"Y_{k}_{t}", lowBound=None) for k in range(1,K+1) for t in range(1,k+1)}
    Rh = {(k,t): pl.LpVariable(f"Rh_{k}_{t}", lowBound=0) for k in range(1,K+1) for t in range(1,k+1)}
    Rp = {(k,t): pl.LpVariable(f"Rp_{k}_{t}", lowBound=0) for k in range(1,K+1) for t in range(1,k+1)}
    Wv = pl.LpVariable('W', lowBound=0)

    # u bounds (box)
    for k in range(1, K+1):
        if k == 1:
            mdl += u0[1] >= 0
            mdl += u0[1] <= M * v[1]
        else:
            x_abs = {t: pl.LpVariable(f"xabs_{k}_{t}", lowBound=0) for t in range(1,k)}
            for t in range(1,k):
                mdl += -x_abs[t] <= A[(k,t)]
                mdl +=  A[(k,t)] <= x_abs[t]
            mdl += u0[k] - pl.lpSum(delta[t-1]*x_abs[t] for t in range(1,k)) >= 0
            mdl += u0[k] + pl.lpSum(delta[t-1]*x_abs[t] for t in range(1,k)) <= M * v[k]

    cumd = np.cumsum(d_hat)
    for k in range(1, K+1):
        const_k = I1 + pl.lpSum(u0[i] for i in range(1, k+1)) - float(cumd[k-1])
        coeff = {}
        for t in range(1, k+1):
            coeff[t] = pl.lpSum(A[(i,t)] for i in range(max(t+1,2), k+1) if (i,t) in A)
            if t == k:
                coeff[t] = coeff[t] + (-1)
        for t in range(1, k+1):
            mdl += -Rh[(k,t)] <= (Y[(k,t)] - h*coeff[t])
            mdl += (Y[(k,t)] - h*coeff[t]) <= Rh[(k,t)]
            mdl += -Rp[(k,t)] <= (-p*coeff[t] - Y[(k,t)])
            mdl += (-p*coeff[t] - Y[(k,t)]) <= Rp[(k,t)]
        y_const = y0[k] + pl.lpSum(Y[(k,t)]*d_hat[t-1] for t in range(1, k+1))
        mdl += y_const >= h*const_k + pl.lpSum(delta[t-1]*Rh[(k,t)] for t in range(1, k+1))
        mdl += y_const >= p*(-const_k) + pl.lpSum(delta[t-1]*Rp[(k,t)] for t in range(1, k+1))

    n = {t: pl.LpVariable(f"n_{t}", lowBound=0) for t in range(1, K+1)}
    for t in range(1, K+1):
        coeff_t = pl.lpSum(A[(i,t)] for i in range(max(t+1,2), K+1) if (i,t) in A)
        mdl += -n[t] <= c * coeff_t
        mdl += c * coeff_t <= n[t]

    # 目标
    mdl += Wv
    term_costs = []
    for k in range(1, K+1):
        y_const = y0[k] + pl.lpSum([Y[(k,t)]*d_hat[t-1] for t in range(1, k+1)])
        term_costs.append(f*v[k] + c*u0[k] + y_const)
    mdl += Wv >= pl.lpSum(term_costs) + pl.lpSum([delta[t-1]*n[t] for t in range(1, K+1)])
    mdl.setObjective(Wv)
    return mdl, dict(v=v, u0=u0, A=A, y0=y0, Y=Y)

# Static (box)
def build_static_box():
    mdl = pl.LpProblem("Static_box", pl.LpMinimize)
    vs = pl.LpVariable.dicts('v', list(range(1, K+1)), lowBound=0, upBound=1, cat=pl.LpBinary)
    us = pl.LpVariable.dicts('u', list(range(1, K+1)), lowBound=0)
    ys = pl.LpVariable.dicts('y', list(range(1, K+1)), lowBound=0)
    for k in range(1, K+1):
        mdl += us[k] >= 0
        mdl += us[k] <= M * vs[k]
    cumd = np.cumsum(d_hat)
    for k in range(1, K+1):
        const_k = I1 + pl.lpSum(us[i] for i in range(1, k+1)) - float(cumd[k-1])
        Sh = pl.LpVariable(f"Sh_{k}", lowBound=0); Sp = pl.LpVariable(f"Sp_{k}", lowBound=0)
        mdl += -Sh <= -h; mdl += -h <= Sh
        mdl += -Sp <= +p; mdl += +p <= Sp
        mdl += ys[k] >= h*const_k + delta[k-1]*Sh
        mdl += ys[k] >= p*(-const_k) + delta[k-1]*Sp
    Wv = pl.LpVariable('W', lowBound=0)
    mdl += Wv >= pl.lpSum(f*vs[k] + c*us[k] + ys[k] for k in range(1, K+1))
    mdl.setObjective(Wv)
    return mdl, dict(v=vs, u=us, y=ys)

mdl_aar_box, vars_aar_box = build_aar_box()
mdl_sta_box, vars_sta_box = build_static_box()

_ = mdl_aar_box.solve(pl.PULP_CBC_CMD(msg=False, timeLimit=180))
_ = mdl_sta_box.solve(pl.PULP_CBC_CMD(msg=False, timeLimit=120))
print('[S2-建模] AAR/Static(Box) 求解完成')

# %%
# S2-3 仅 Box：评估与可视化

# 提取解
def _sol_affine(vdict):
    v = np.array([pl.value(vdict['v'][k]) for k in range(1, K+1)])
    u0 = np.array([pl.value(vdict['u0'][k]) for k in range(1, K+1)])
    A = np.zeros((K,K))
    for k in range(1, K+1):
        for t in range(1, k):
            A[k-1,t-1] = pl.value(vdict['A'][(k,t)]) if (k,t) in vdict['A'] else 0.0
    return v, u0, A

def _sol_static(vdict):
    v = np.array([pl.value(vdict['v'][k]) for k in range(1, K+1)])
    u = np.array([pl.value(vdict['u'][k]) for k in range(1, K+1)])
    return v, u

vA, u0A, AA = _sol_affine(vars_aar_box)
vS, uS = _sol_static(vars_sta_box)

costs = (f,c,h,p)
a_eval = evaluate(u0A, AA, vA, d_hat, delta, I1, costs)
s_eval = evaluate(uS, None, vS, d_hat, delta, I1, costs)

# 历史评估（若有真实 demand 列）
hist_rows = {}
if 'demand' in forecast_df.columns:
    d_real = forecast_df.groupby('period', as_index=False)['demand'].sum().head(K)['demand'].to_numpy()
    z_hist = d_real - d_hat
    a_hist = simulate_trajectory(affine_policy_orders(u0A, AA, z_hist), vA, d_hat, z_hist, I1, costs)
    s_hist = simulate_trajectory(affine_policy_orders(uS, None, z_hist), vS, d_hat, z_hist, I1, costs)
    hist_rows['AAR-Box'] = a_hist
    hist_rows['Static-Box'] = s_hist

summary_box = pd.DataFrame([
    dict(method='AAR-Box', worst_obj=float(pl.value(mdl_aar_box.objective) or 0.0),
         nominal_total=a_eval['nominal']['total'], nominal_service=a_eval['nominal']['service_rate'],
         MC_mean_total=a_eval['mc']['total']['mean'], MC_std_total=a_eval['mc']['total']['std'],
         MC_VaR95=a_eval['mc']['VaR95'], MC_CVaR95=a_eval['mc']['CVaR95'], MC_mean_service=a_eval['mc']['service']['mean'],
         historical_total=(hist_rows.get('AAR-Box',{}).get('total') if hist_rows else None),
         historical_service=(hist_rows.get('AAR-Box',{}).get('service_rate') if hist_rows else None),
         historical_stockouts=(hist_rows.get('AAR-Box',{}).get('stockouts') if hist_rows else None)),
    dict(method='Static-Box', worst_obj=float(pl.value(mdl_sta_box.objective) or 0.0),
         nominal_total=s_eval['nominal']['total'], nominal_service=s_eval['nominal']['service']['rate'] if False else s_eval['nominal']['service_rate'],
         MC_mean_total=s_eval['mc']['total']['mean'], MC_std_total=s_eval['mc']['total']['std'],
         MC_VaR95=s_eval['mc']['VaR95'], MC_CVaR95=s_eval['mc']['CVaR95'], MC_mean_service=s_eval['mc']['service']['mean'],
         historical_total=(hist_rows.get('Static-Box',{}).get('total') if hist_rows else None),
         historical_service=(hist_rows.get('Static-Box',{}).get('service_rate') if hist_rows else None),
         historical_stockouts=(hist_rows.get('Static-Box',{}).get('stockouts') if hist_rows else None))
])
display(summary_box)

# 随机分布对比
rng = np.random.default_rng(101)
N = 400
records = {}
for name, (v_, u0_, A_) in {'AAR-Box':(vA,u0A,AA)}.items():
    totals = []
    for _ in range(N):
        z = rng.uniform(low=-delta, high=+delta)
        totals.append(simulate_trajectory(affine_policy_orders(u0_, A_, z), v_, d_hat, z, I1, costs)['total'])
    records[name] = totals

# Static
totals = []
for _ in range(N):
    z = rng.uniform(low=-delta, high=+delta)
    totals.append(simulate_trajectory(affine_policy_orders(uS, None, z), vS, d_hat, z, I1, costs)['total'])
records['Static-Box'] = totals

plot_distributions(records)

# %%
# S3-1 四类不确定集：AAR 与 Static 构建

# 复用先前封装：AAR 的四集合（box/poly/ell1/wass）
# 直接复用 models, models_static 的构建逻辑

# AAR 四集合
models = {}
for name in ['box','poly','ell1','wass']:
    if name == 'box':
        mdl, vars_ = build_aar_box()
    elif name == 'poly':
        mdl, vars_ = build_aar_with_envelope('poly')
    elif name == 'ell1':
        mdl, vars_ = build_aar_with_envelope2('ell1')
    elif name == 'wass':
        mdl, vars_ = build_aar_with_envelope2('wass')
    models[name] = (mdl, vars_)
    _ = mdl.solve(pl.PULP_CBC_CMD(msg=False, timeLimit=120))

# Static 四集合
models_static = {}
for name in ['box','poly','ell1','wass']:
    mdl, vars_ = build_static_with_envelope(name)
    models_static[name] = (mdl, vars_)
    _ = mdl.solve(pl.PULP_CBC_CMD(msg=False, timeLimit=120))

print('[S3-建模] AAR/Static (box/poly/ell1/wass) 求解完成')

# %%
# S3-2 四集合：统一评估表

def _extract_solution(vars_, affine=True):
    if affine:
        v = np.array([pl.value(vars_['v'][k]) for k in range(1, K+1)])
        u0 = np.array([pl.value(vars_['u0'][k]) for k in range(1, K+1)])
        A = np.zeros((K,K))
        for k in range(1, K+1):
            for t in range(1, k):
                A[k-1,t-1] = pl.value(vars_['A'][(k,t)]) if (k,t) in vars_['A'] else 0.0
        return v, u0, A
    else:
        v = np.array([pl.value(vars_['v'][k]) for k in range(1, K+1)])
        u = np.array([pl.value(vars_['u'][k]) for k in range(1, K+1)])
        return v, u, None

rows = []
# 历史真实（如可用）
hist_avail = 'demand' in forecast_df.columns
if hist_avail:
    d_real = forecast_df.groupby('period', as_index=False)['demand'].sum().head(K)['demand'].to_numpy()
    z_hist = d_real - d_hat

for name, (mdl, vdict) in models.items():
    v, u0, A = _extract_solution(vdict, True)
    ev = evaluate(u0, A, v, d_hat, delta, I1, (f,c,h,p), num_mc=200, seed=1357)
    hist = None
    if hist_avail:
        hist = simulate_trajectory(affine_policy_orders(u0, A, z_hist), v, d_hat, z_hist, I1, (f,c,h,p))
    rows.append(dict(method=f'AAR-{name}', worst_obj=float(pl.value(mdl.objective) or 0.0),
                     nominal_total=ev['nominal']['total'], nominal_service=ev['nominal']['service_rate'],
                     MC_mean_total=ev['mc']['total']['mean'], MC_std_total=ev['mc']['total']['std'],
                     MC_VaR95=ev['mc']['VaR95'], MC_CVaR95=ev['mc']['CVaR95'], MC_mean_service=ev['mc']['service']['mean'],
                     historical_total=(None if hist is None else hist['total']),
                     historical_service=(None if hist is None else hist['service_rate']),
                     historical_stockouts=(None if hist is None else hist['stockouts'])))

for name, (mdl, vdict) in models_static.items():
    v, u, _ = _extract_solution(vdict, False)
    ev = evaluate(u, None, v, d_hat, delta, I1, (f,c,h,p), num_mc=200, seed=2468)
    hist = None
    if hist_avail:
        hist = simulate_trajectory(affine_policy_orders(u, None, z_hist), v, d_hat, z_hist, I1, (f,c,h,p))
    rows.append(dict(method=f'Static-{name}', worst_obj=float(pl.value(mdl.objective) or 0.0),
                     nominal_total=ev['nominal']['total'], nominal_service=ev['nominal']['service_rate'],
                     MC_mean_total=ev['mc']['total']['mean'], MC_std_total=ev['mc']['total']['std'],
                     MC_VaR95=ev['mc']['VaR95'], MC_CVaR95=ev['mc']['CVaR95'], MC_mean_service=ev['mc']['service']['mean'],
                     historical_total=(None if hist is None else hist['total']),
                     historical_service=(None if hist is None else hist['service_rate']),
                     historical_stockouts=(None if hist is None else hist['stockouts'])))

compare_all = pd.DataFrame(rows)
display(compare_all.sort_values('method').reset_index(drop=True))

# %%
# S3-3 四集合：随机分布可视化
rng = np.random.default_rng(4242)
N = 300
records = {}

# AAR
for name, (mdl, vdict) in models.items():
    v, u0, A = np.array([pl.value(vdict['v'][k]) for k in range(1, K+1)]), \
               np.array([pl.value(vdict['u0'][k]) for k in range(1, K+1)]), \
               np.zeros((K,K))
    for k in range(1, K+1):
        for t in range(1, k):
            A[k-1,t-1] = pl.value(vdict['A'][(k,t)]) if (k,t) in vdict['A'] else 0.0
    totals = []
    for _ in range(N):
        z = rng.uniform(low=-delta, high=+delta)
        totals.append(simulate_trajectory(affine_policy_orders(u0, A, z), v, d_hat, z, I1, (f,c,h,p))['total'])
    records[f'AAR-{name}'] = totals

# Static
for name, (mdl, vdict) in models_static.items():
    v = np.array([pl.value(vdict['v'][k]) for k in range(1, K+1)])
    u = np.array([pl.value(vdict['u'][k]) for k in range(1, K+1)])
    totals = []
    for _ in range(N):
        z = rng.uniform(low=-delta, high=+delta)
        totals.append(simulate_trajectory(affine_policy_orders(u, None, z), v, d_hat, z, I1, (f,c,h,p))['total'])
    records[f'Static-{name}'] = totals

plot_distributions(records)

# %%
# S4-1 非鲁棒（名义）优化：以 d_hat 为确定需求的 Static 基线

def build_nominal_static():
    mdl = pl.LpProblem("Nominal_Static", pl.LpMinimize)
    v = pl.LpVariable.dicts('v', list(range(1, K+1)), lowBound=0, upBound=1, cat=pl.LpBinary)
    u = pl.LpVariable.dicts('u', list(range(1, K+1)), lowBound=0)
    S = pl.LpVariable.dicts('S', list(range(1, K+1)), lowBound=None)  # 库存（可正可负）
    Ipos = pl.LpVariable.dicts('Ipos', list(range(1, K+1)), lowBound=0)
    Ineg = pl.LpVariable.dicts('Ineg', list(range(1, K+1)), lowBound=0)

    # 启动约束
    for k in range(1, K+1):
        mdl += u[k] <= M * v[k]

    # 库存递推与分解
    mdl += S[1] == I1 + u[1] - float(d_hat[0])
    for k in range(2, K+1):
        mdl += S[k] == S[k-1] + u[k] - float(d_hat[k-1])
    for k in range(1, K+1):
        mdl += S[k] == Ipos[k] - Ineg[k]

    # 目标
    W = pl.LpVariable('W_nom', lowBound=0)
    mdl += W >= pl.lpSum([f*v[k] + c*u[k] + h*Ipos[k] + p*Ineg[k] for k in range(1, K+1)])
    mdl.setObjective(W)
    return mdl, dict(v=v, u=u, S=S, Ipos=Ipos, Ineg=Ineg)

mdl_nom, vars_nom = build_nominal_static()
_ = mdl_nom.solve(pl.PULP_CBC_CMD(msg=False, timeLimit=60))
print('[S4] Nominal-Static 求解完成:', pl.LpStatus[mdl_nom.status], 'obj=', float(pl.value(mdl_nom.objective) or 0.0))

# %%
# S4-2 与 AAR/Static(Box) 对比（名义与随机）

# 取 S2-2 已得到的 AAR-Box / Static-Box 解
vA, u0A, AA = np.array([pl.value(vars_aar_box['v'][k]) for k in range(1, K+1)]), \
               np.array([pl.value(vars_aar_box['u0'][k]) for k in range(1, K+1)]), \
               np.zeros((K,K))
for k in range(1, K+1):
    for t in range(1, k):
        AA[k-1,t-1] = pl.value(vars_aar_box['A'][(k,t)]) if (k,t) in vars_aar_box['A'] else 0.0

vS, uS = np.array([pl.value(vars_sta_box['v'][k]) for k in range(1, K+1)]), \
         np.array([pl.value(vars_sta_box['u'][k]) for k in range(1, K+1)])

vN, uN = np.array([pl.value(vars_nom['v'][k]) for k in range(1, K+1)]), \
         np.array([pl.value(vars_nom['u'][k]) for k in range(1, K+1)])

costs = (f,c,h,p)

a_eval = evaluate(u0A, AA, vA, d_hat, delta, I1, costs, num_mc=400, seed=9001)
s_eval = evaluate(uS, None, vS, d_hat, delta, I1, costs, num_mc=400, seed=9002)
# 名义静态在随机下也评估（策略固定）
n_eval = evaluate(uN, None, vN, d_hat, delta, I1, costs, num_mc=400, seed=9003)

s4_df = pd.DataFrame([
    dict(method='AAR-Box', worst_obj=float(pl.value(mdl_aar_box.objective) or 0.0),
         nominal_total=a_eval['nominal']['total'], MC_mean_total=a_eval['mc']['total']['mean'],
         MC_VaR95=a_eval['mc']['VaR95'], MC_CVaR95=a_eval['mc']['CVaR95'], nominal_service=a_eval['nominal']['service_rate']),
    dict(method='Static-Box', worst_obj=float(pl.value(mdl_sta_box.objective) or 0.0),
         nominal_total=s_eval['nominal']['total'], MC_mean_total=s_eval['mc']['total']['mean'],
         MC_VaR95=s_eval['mc']['VaR95'], MC_CVaR95=s_eval['mc']['CVaR95'], nominal_service=s_eval['nominal']['service_rate']),
    dict(method='Nominal-Static', worst_obj=float(pl.value(mdl_nom.objective) or 0.0),
         nominal_total=n_eval['nominal']['total'], MC_mean_total=n_eval['mc']['total']['mean'],
         MC_VaR95=n_eval['mc']['VaR95'], MC_CVaR95=n_eval['mc']['CVaR95'], nominal_service=n_eval['nominal']['service_rate'])
])

display(s4_df)

# 可视化随机分布
rng = np.random.default_rng(9012)
N = 400
records = {}
for name, (v_, u0_, A_) in {'AAR-Box':(vA,u0A,AA)}.items():
    totals = []
    for _ in range(N):
        z = rng.uniform(low=-delta, high=+delta)
        totals.append(simulate_trajectory(affine_policy_orders(u0_, A_, z), v_, d_hat, z, I1, costs)['total'])
    records[name] = totals

for name, (v_, u_) in {'Static-Box':(vS,uS), 'Nominal-Static':(vN,uN)}.items():
    totals = []
    for _ in range(N):
        z = rng.uniform(low=-delta, high=+delta)
        totals.append(simulate_trajectory(affine_policy_orders(u_, None, z), v_, d_hat, z, I1, costs)['total'])
    records[name] = totals

plot_distributions(records)

# %% [markdown]
# # 单品 AAR 鲁棒库存优化（14天决策周期, Final）
#
# - 基于 Ben-Tal 等（2004）的仿射可调鲁棒（AAR）与 Box 不确定集的对偶等价重构。
# - 仅保留“最终版”模型：
#   - AAR：u 仿射、y 单一且可仿射（避免双计费），鲁棒包络进入约束，目标含 y 与 ∑δ·n。
#   - Static 基线：u 静态、y 静态（不仿射），用于对比体现 AAR 的提升。
# - 含完整评估指标与可视化：成本分解、服务水平、随机稳健性、VaR/CVaR。

# %%
# 依赖与环境
import sys, subprocess, os

def ensure(pkg):
    try:
        __import__(pkg)
    except ImportError:
        subprocess.check_call([sys.executable, "-m", "pip", "install", pkg])

for p in ["pandas", "numpy", "pulp", "matplotlib", "seaborn", "openpyxl"]:
    ensure(p)

import pandas as pd
import numpy as np
import pulp as pl
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 120)
np.random.seed(42)
print("依赖加载完成")

# %%
# 参数区
PRODUCT = "电解镍"
T_days = 14
K_periods = 8

# 成本
h = 1.0
p = 10.0
c = 0.0
f = 100.0
M = 1e6

# 不确定强度
delta_ratio = 0.2
I1 = 0.0

# %%
# 统一数据读入与不确定性构造（合并版，替代下方旧读入单元）
# - 来源优先级：逐日详细结果xlsx > 逐周汇总xlsx > all_future_predictions.csv > 合成
# - 最优模型：读取“逐日预测模型性能对比*.xlsx”，按 MAE/RMSE/MAPE/WMAPE 等权平均名次选取
# - 仅此单元完成：中心预测 d_hat、Box/Poly/椭球/Wasserstein 半径与导出、元信息记录
import os, glob, re, json, warnings
import numpy as np
import pandas as pd

# ---------- 工具 ----------

def _safe_read_excel(path: str):
    try:
        return pd.read_excel(path)
    except Exception:
        try:
            return pd.read_excel(path, engine='openpyxl')
        except Exception:
            return None

def _find_files():
    return {
        'detail': sorted(glob.glob('**/*逐日预测详细结果*.xlsx', recursive=True)),
        'weekly': sorted(glob.glob('**/*逐日预测汇总结果*.xlsx', recursive=True)),
        'perf':   sorted(glob.glob('**/*逐日预测模型性能对比*.xlsx', recursive=True)),
        'csv':    sorted(glob.glob('**/all_future_predictions.csv', recursive=True)),
    }

# 读取性能对比，返回最优模型名（四指标等权平均名次，低者优）

def _best_model_from_perf(perf_paths):
    if not perf_paths:
        return None
    dfp = _safe_read_excel(perf_paths[0])
    if not isinstance(dfp, pd.DataFrame) or dfp.empty:
        return None
    # 模型列
    model_col = None
    for c in dfp.columns:
        lc = str(c).lower()
        if ('model' in lc) or ('模型' in str(c)):
            model_col = c; break
    if model_col is None:
        model_col = dfp.columns[0]
    # 指标列
    def _find(keys):
        keys = [k.lower() for k in keys]
        for c in dfp.columns:
            lc = str(c).lower()
            if any(k in lc for k in keys):
                if 'wmape' in lc and 'mape' in keys:
                    continue
                return c
        return None
    cols = [_find(['mae']), _find(['rmse']), _find(['mape']), _find(['wmape'])]
    cols = [c for c in cols if c is not None]
    if not cols:
        return None
    ranks = dfp[cols].rank(ascending=True, method='average')
    dfp['avg_rank'] = ranks.mean(axis=1)
    best = dfp.sort_values('avg_rank', kind='mergesort').iloc[0]
    return str(best[model_col])

# 名称归一 + 前缀匹配
_syn = {
    'xgboost':'XGBoost','lightgbm':'LightGBM','catboost':'CatBoost',
    'randomforest':'RandomForest','random_forest':'RandomForest',
    'linearregression':'LinearRegression','linear':'LinearRegression','ols':'LinearRegression',
    'qrf':'QRF','quantileforest':'QRF','quantilerandomforest':'QRF',
    'svr':'SVR','lstm':'LSTM','best':'Best'
}

def _norm(name: str) -> str:
    key = re.sub(r'[^a-z]', '', str(name).lower())
    return _syn.get(key, name)

def _avail_prefixes(df: pd.DataFrame):
    return sorted(set(re.sub(r'_prediction$', '', c) for c in df.columns if str(c).endswith('_prediction')))

def _pick_prefix(best_name: str, df: pd.DataFrame):
    prefs = _avail_prefixes(df)
    if not prefs:
        return None
    if best_name:
        nn = _norm(best_name)
        for p in prefs:
            if nn.lower() in p.lower() or p.lower() in nn.lower():
                return p
    # 回退优先：QRF > XGBoost > LightGBM > RandomForest > LinearRegression > SVR > LSTM > Best
    pri = ['QRF','XGBoost','LightGBM','RandomForest','LinearRegression','SVR','LSTM','Best']
    for p in pri:
        if any(p.lower()==q.lower() for q in prefs):
            return p
    return prefs[0]

# ---------- 主流程 ----------
files = _find_files()
perf_best = _best_model_from_perf(files['perf'])

# 读取逐日 or 逐周 or CSV
forecast_df = None
source = None
chosen_prefix = None

if files['detail']:
    df = _safe_read_excel(files['detail'][0])
    if isinstance(df, pd.DataFrame) and not df.empty:
        forecast_df = df.copy(); source = 'daily_detail_xlsx'
elif files['weekly']:
    dfw = _safe_read_excel(files['weekly'][0])
    if isinstance(dfw, pd.DataFrame) and not dfw.empty:
        # 逐周→14天：两周合并
        dfw = dfw.copy()
        if 'week_start' not in dfw.columns:
            c0 = next((c for c in dfw.columns if 'week' in c.lower() or 'date' in c.lower()), None)
            if c0: dfw.rename(columns={c0:'week_start'}, inplace=True)
        dfw['week_start'] = pd.to_datetime(dfw['week_start'], errors='coerce')
        dfw = dfw.sort_values('week_start').reset_index(drop=True)
        # 对各模型 *_forecast 列，每两行求和
        fcols = [c for c in dfw.columns if c.endswith('_forecast')]
        if len(dfw)%2==1: dfw = dfw.iloc[:-1]
        dfw['period'] = (dfw.index // 2) + 1
        # 转成“逐日风格”以复用后续逻辑
        long = []
        for c in fcols:
            tmp = dfw[['period', c]].copy()
            pref = c.replace('_forecast','')
            tmp.rename(columns={c: f'{pref}_prediction'}, inplace=True)
            long.append(tmp)
        # 期级“伪逐日”展开：每期1行
        if long:
            base = long[0][['period']].copy()
            for t in long:
                base = base.merge(t, on='period', how='left')
            base['date'] = pd.to_datetime('2025-01-01') + pd.to_timedelta((base['period']-1)*T_days, unit='D')
            forecast_df = base
            source = 'weekly_summary_xlsx'
elif files['csv']:
    try:
        dfc = pd.read_csv(files['csv'][0])
        if {'date','prediction'} <= set(dfc.columns):
            dfc['date'] = pd.to_datetime(dfc['date'], errors='coerce')
            dfc = dfc.sort_values('date')
            dfc['period'] = ((dfc['date'] - dfc['date'].min()).dt.days // T_days) + 1
            agg = dfc.groupby('period', as_index=False)['prediction'].sum()
            forecast_df = agg.rename(columns={'prediction':'Baseline_prediction'})
            forecast_df['date'] = pd.to_datetime('2025-01-01') + pd.to_timedelta((forecast_df['period']-1)*T_days, unit='D')
            source = 'all_future_predictions.csv'
    except Exception:
        pass

# 合成兜底
if forecast_df is None:
    days = T_days * K_periods
    date_index = pd.date_range(start="2025-01-01", periods=days, freq="D")
    base = 1000
    season = 200*np.sin(np.arange(days)/7*2*np.pi)
    noise = np.random.normal(0, 50, size=days)
    pred = np.maximum(base + season + noise, 100)
    dfc = pd.DataFrame({'date': date_index, 'prediction': pred})
    dfc['period'] = ((dfc['date'] - dfc['date'].min()).dt.days // T_days) + 1
    agg = dfc.groupby('period', as_index=False)['prediction'].sum()
    forecast_df = agg.rename(columns={'prediction':'Baseline_prediction'})
    forecast_df['date'] = pd.to_datetime('2025-01-01') + pd.to_timedelta((forecast_df['period']-1)*T_days, unit='D')
    source = 'synthetic'

# 统一期号与日期
if 'date' in forecast_df.columns:
    forecast_df['date'] = pd.to_datetime(forecast_df['date'], errors='coerce')
if 'period' not in forecast_df.columns:
    forecast_df['period'] = ((forecast_df['date'] - forecast_df['date'].min()).dt.days // T_days) + 1

# 选前缀（最优模型）
chosen_prefix = _pick_prefix(perf_best, forecast_df)

# ---------- 构造 d_hat / 不确定集 ----------

def _col(prefix: str, suffixes):
    for sfx in suffixes:
        c = f"{prefix}_{sfx}"
        if c in forecast_df.columns:
            return c
    return None

pred_col = _col(chosen_prefix, ['prediction']) or ('Best_prediction' if 'Best_prediction' in forecast_df.columns else None)
lo_col   = _col(chosen_prefix, ['band_lo','ellip_lo_90'])
hi_col   = _col(chosen_prefix, ['band_hi','ellip_hi_90'])
q90_col  = _col(chosen_prefix, ['roll_abs_q90_28d'])
mae_col  = _col(chosen_prefix, ['roll_mae_28d'])
std_col  = _col(chosen_prefix, ['roll_std_28d'])

z90 = 1.645

# 逐日生成 lo/hi/sigma/w1
_df = forecast_df.copy()
_df['_pred'] = pd.to_numeric(_df[pred_col], errors='coerce') if pred_col else np.nan
if lo_col and hi_col:
    _df['_lo'] = pd.to_numeric(_df[lo_col], errors='coerce')
    _df['_hi'] = pd.to_numeric(_df[hi_col], errors='coerce')
else:
    mag = None
    for candi in [q90_col, mae_col, std_col]:
        if candi is None: continue
        v = pd.to_numeric(_df[candi], errors='coerce')
        if candi == std_col:
            v = z90 * v
        mag = v; break
    if mag is None:
        mag = delta_ratio * _df['_pred']
    _df['_lo'] = _df['_pred'] - mag
    _df['_hi'] = _df['_pred'] + mag
_df['_lo'] = _df['_lo'].clip(lower=0)

# sigma（L2 椭球）
if std_col:
    _df['_sigma'] = pd.to_numeric(_df[std_col], errors='coerce')
elif q90_col:
    _df['_sigma'] = pd.to_numeric(_df[q90_col], errors='coerce') / z90
elif mae_col:
    _df['_sigma'] = 1.25 * pd.to_numeric(_df[mae_col], errors='coerce')
else:
    _df['_sigma'] = 0.2 * _df['_pred']

# W1 半径（逐日）
if 'W1_radius_best_28d' in _df.columns:
    _df['_w1'] = pd.to_numeric(_df['W1_radius_best_28d'], errors='coerce')
elif q90_col:
    _df['_w1'] = pd.to_numeric(_df[q90_col], errors='coerce')
elif mae_col:
    _df['_w1'] = 1.25 * pd.to_numeric(_df[mae_col], errors='coerce')
else:
    _df['_w1'] = 0.2 * _df['_pred']

# 聚合到期
agg_pred  = _df.groupby('period')['_pred'].sum()
agg_lo    = _df.groupby('period')['_lo'].sum()
agg_hi    = _df.groupby('period')['_hi'].sum()
agg_sigma = _df.groupby('period')['_sigma'].apply(lambda s: float(np.sqrt(np.nansum(np.square(s.to_numpy())))))
agg_w1    = _df.groupby('period')['_w1'].sum()

# 结果向量（裁剪 K_periods）
d_hat = agg_pred.to_numpy()[:K_periods].astype(float)
box_delta = np.maximum(agg_hi.to_numpy() - agg_pred.to_numpy(), agg_pred.to_numpy() - agg_lo.to_numpy())[:K_periods].astype(float)
K = len(d_hat)

# Poly 相邻差分界
poly_beta_prev = (box_delta[:-1] + box_delta[1:]).astype(float) if K>1 else np.array([], dtype=float)

# 椭球 / Wasserstein 半径（全局）
rho = float(1.645 * np.linalg.norm(agg_sigma.to_numpy()[:K], ord=2))
rho1 = float(np.sqrt(K) * rho)
w_eps = float(np.linalg.norm(agg_w1.to_numpy()[:K], ord=2))
w_radius_abs = float(np.max(agg_w1.to_numpy()[:K]))

# 输出 CSV + 元信息 JSON
delta = box_delta.copy()
try:
    out = pd.DataFrame({'period': np.arange(1, K+1), 'd_hat': d_hat, 'box_delta': box_delta})
    out['poly_beta_prev'] = pd.Series(poly_beta_prev).reindex(range(K), fill_value=np.nan)
    out.to_csv('uncertainty_14d_constructed.csv', index=False)
    meta = {
        'source': source,
        'central_model_from_perf': perf_best,
        'central_prefix_chosen': chosen_prefix,
        'box_method': 'bands' if (lo_col and hi_col) else ('q90/mae/std/ratio_fallback'),
        'poly_method': 'adjacent_sum_of_box',
        'ell2_method': 'std' if std_col else ('q90->std' if q90_col else ('mae->std' if mae_col else 'heuristic')),
        'wass_method': 'W1_radius_best_28d' if 'W1_radius_best_28d' in _df.columns else ('q90' if q90_col else ('mae' if mae_col else 'heuristic')),
        'K_periods': int(K),
        'rho': rho, 'w_eps_L2': w_eps, 'w_radius_abs': w_radius_abs,
    }
    with open('uncertainty_14d_meta.json','w',encoding='utf-8') as f:
        json.dump(meta, f, ensure_ascii=False, indent=2)
    print('已导出: uncertainty_14d_constructed.csv, uncertainty_14d_meta.json')
except Exception as e:
    warnings.warn(f'导出失败: {e}')

print(f"不确定性来源: {source} | 最优模型: {perf_best} -> 列前缀 {chosen_prefix}")
print(f"K={K}, box均值比例≈{float(np.mean(box_delta/np.maximum(d_hat,1e-6))):.3f}, ρ≈{rho:.2f}, W1(L2)≈{w_eps:.2f}")

# %%
# 构造不确定性集合输入（优先使用“单日预测聚合”输出；回退到旧CSV或合成）
import os, warnings, glob
import pandas as pd, numpy as np


def _safe_read_excel(path: str):
    try:
        return pd.read_excel(path)
    except Exception:
        try:
            return pd.read_excel(path, engine='openpyxl')
        except Exception:
            return None


def find_new_outputs(root: str = '.'):
    patterns = [
        '*逐日预测详细结果*.xlsx',
        '*逐日预测汇总结果*.xlsx',
        'all_future_predictions.csv',
    ]
    found = []
    for pat in patterns:
        found.extend(glob.glob(os.path.join(root, '**', pat), recursive=True))
    # 排序优先级：详细 > 汇总 > 旧CSV
    found_sorted = sorted(found, key=lambda p: (0 if '详细' in os.path.basename(p) else (1 if '汇总' in os.path.basename(p) else 2), len(p)))
    return found_sorted


def build_from_daily_detail(df_daily: pd.DataFrame):
    """从逐日详细结果构造14天期的中心预测 d_hat 与不确定带 delta。
    规则：按模型列（*_prediction）逐日求和到 14 天周期，中心值优先 Improved_Ensemble；
    delta 取 10%-90% 分位的对称半宽，空缺回退为比例法。
    返回：d_hat, delta, per_model_table, info, df_with_period
    """
    df = df_daily.copy()
    # 统一日期列
    if 'date' not in df.columns:
        cand = [c for c in df.columns if 'date' in c.lower() or '日期' in c]
        if cand:
            df.rename(columns={cand[0]: 'date'}, inplace=True)
    df['date'] = pd.to_datetime(df['date'], errors='coerce')
    df = df.sort_values('date')

    # 识别实际与预测列
    actual_cols = [c for c in df.columns if c.lower() in ('demand', 'actual_demand', 'actual')]
    pred_cols = [c for c in df.columns if (c.endswith('_prediction') or c.endswith('_pred') or 'prediction' in c.lower()) and c not in actual_cols]
    pred_cols = [c for c in pred_cols if not df[c].isna().all()]

    # 构造14天周期
    df['period'] = ((df['date'] - df['date'].min()).dt.days // T_days) + 1
    per_model = df.groupby('period')[pred_cols].sum(min_count=1)

    # 选择中心列
    priority = ['Improved_Ensemble', 'XGBoost', 'LightGBM', 'CatBoost', 'RandomForest', 'LinearRegression']
    chosen = None
    for name in priority:
        col = next((c for c in pred_cols if c.lower().startswith(name.lower() + '_') or name.lower() in c.lower()), None)
        if col is not None and col in per_model.columns and not per_model[col].isna().all():
            chosen = col
            break
    if chosen is None:
        per_model['central'] = per_model.median(axis=1, skipna=True)
        chosen = 'central'

    d_hat_vec = per_model[chosen].to_numpy()
    q_low = per_model.quantile(0.1, axis=1, numeric_only=True)
    q_high = per_model.quantile(0.9, axis=1, numeric_only=True)
    delta_vec = np.maximum(q_high.to_numpy() - d_hat_vec, d_hat_vec - q_low.to_numpy())

    # 回退：无效处使用比例法
    fallback = delta_ratio * d_hat_vec
    bad = ~np.isfinite(delta_vec) | (delta_vec <= 0)
    delta_vec[bad] = fallback[bad]

    info = dict(source='daily_detail_xlsx', n_models=int(per_model.shape[1]), chosen=chosen, model_cols=list(per_model.columns))
    return d_hat_vec, delta_vec, per_model.reset_index(), info, df


def build_from_weekly_summary(df_weekly: pd.DataFrame):
    """从逐周汇总结果构造14天期（两周合并）的 d_hat 与 delta。"""
    df = df_weekly.copy()
    # 时间列
    if 'week_start' not in df.columns:
        cand = [c for c in df.columns if 'week' in c.lower() or 'date' in c.lower()]
        if cand:
            df.rename(columns={cand[0]: 'week_start'}, inplace=True)
    df['week_start'] = pd.to_datetime(df['week_start'], errors='coerce')
    df = df.sort_values('week_start').reset_index(drop=True)

    # 预测列
    fcols = [c for c in df.columns if c.endswith('_forecast') or 'forecast' in c.lower()]
    fcols = [c for c in fcols if c not in ('actual_weekly_demand',)]
    fcols = [c for c in fcols if not df[c].isna().all()]

    # 每两周合并为 14 天周期
    if len(df) % 2 == 1:
        df = df.iloc[:-1]
    df['period'] = (df.index // 2) + 1
    per_model = df.groupby('period')[fcols].sum(min_count=1)

    # 中心列优先 Improved_Ensemble/ma
    priority = ['Improved_Ensemble', 'XGBoost', 'LightGBM', 'CatBoost', 'RandomForest', 'LinearRegression', 'ma']
    chosen = None
    for name in priority:
        cand = next((c for c in per_model.columns if c.lower().startswith(name.lower()) and 'forecast' in c.lower()), None)
        if cand is not None and not per_model[cand].isna().all():
            chosen = cand
            break
    if chosen is None:
        per_model['central'] = per_model.median(axis=1, skipna=True)
        chosen = 'central'

    d_hat_vec = per_model[chosen].to_numpy()
    q_low = per_model.quantile(0.1, axis=1, numeric_only=True)
    q_high = per_model.quantile(0.9, axis=1, numeric_only=True)
    delta_vec = np.maximum(q_high.to_numpy() - d_hat_vec, d_hat_vec - q_low.to_numpy())

    fallback = delta_ratio * d_hat_vec
    bad = ~np.isfinite(delta_vec) | (delta_vec <= 0)
    delta_vec[bad] = fallback[bad]

    info = dict(source='weekly_summary_xlsx', n_models=int(per_model.shape[1]), chosen=chosen, model_cols=list(per_model.columns))
    return d_hat_vec, delta_vec, per_model.reset_index(), info


# 主流程：按优先级尝试加载
files = find_new_outputs('.')
forecast_df = None
per_model_table = None
info = None

d_hat = None
delta = None

for path in files:
    if path.endswith('.xlsx') and ('详细' in os.path.basename(path)):
        df = _safe_read_excel(path)
        if df is not None:
            try:
                d_hat, delta, per_model_table, info, df_with_period = build_from_daily_detail(df)
                forecast_df = df_with_period  # 含 period 便于后续历史评估
                break
            except Exception as e:
                warnings.warn(f'daily detail parse failed for {os.path.basename(path)}: {e}')
    elif path.endswith('.xlsx') and ('汇总' in os.path.basename(path)):
        df = _safe_read_excel(path)
        if df is not None:
            try:
                d_hat, delta, per_model_table, info = build_from_weekly_summary(df)
                forecast_df = df  # 无 demand 列时后续会自动跳过历史评估
                break
            except Exception as e:
                warnings.warn(f'weekly summary parse failed for {os.path.basename(path)}: {e}')
    elif path.endswith('all_future_predictions.csv'):
        try:
            df = pd.read_csv(path)
            if {'date', 'prediction'} <= set(df.columns):
                forecast_df = df.copy()
                forecast_df['date'] = pd.to_datetime(forecast_df['date'])
                forecast_df = forecast_df.sort_values('date')
                forecast_df['period'] = ((forecast_df['date'] - forecast_df['date'].min()).dt.days // T_days) + 1
                agg = forecast_df.groupby('period', as_index=False)['prediction'].sum().head(K_periods)
                d_hat = agg['prediction'].to_numpy()
                delta = delta_ratio * d_hat
                info = dict(source='all_future_predictions.csv', n_models=1, chosen='prediction', model_cols=['prediction'])
                per_model_table = agg[['period', 'prediction']]
                break
        except Exception:
            pass

# 兜底：生成合成序列
if d_hat is None:
    days = T_days * K_periods
    date_index = pd.date_range(start="2025-01-01", periods=days, freq="D")
    base = 1000
    season = 200 * np.sin(np.arange(days) / 7 * 2 * np.pi)
    noise = np.random.normal(0, 50, size=days)
    pred = np.maximum(base + season + noise, 100)
    forecast_df = pd.DataFrame({'date': date_index, 'prediction': pred})
    forecast_df['period'] = ((forecast_df['date'] - forecast_df['date'].min()).dt.days // T_days) + 1
    agg = forecast_df.groupby('period', as_index=False)['prediction'].sum().head(K_periods)
    d_hat = agg['prediction'].to_numpy()
    delta = delta_ratio * d_hat
    info = dict(source='synthetic', n_models=1, chosen='prediction', model_cols=['prediction'])

# 截断到设定的规划期数
d_hat = np.array(d_hat[:K_periods], dtype=float)
delta = np.array(delta[:K_periods], dtype=float)
K = len(d_hat)

print(f"不确定性来源: {info.get('source')}, 选择列: {info.get('chosen')}, 模型数: {info.get('n_models')}")
print(f"生成 {K} 个14天周期。不确定度均值比例≈{np.mean(delta / np.maximum(d_hat, 1e-6)):.3f}")

# 导出构造后的14天不确定集，便于复现实验
try:
    out_df = pd.DataFrame({'period': np.arange(1, K + 1), 'd_hat': d_hat, 'delta': delta})
    out_df.to_csv('uncertainty_14d_constructed.csv', index=False)
    print('已导出不确定集文件: uncertainty_14d_constructed.csv')
except Exception as _e:
    print('导出不确定集文件失败:', _e)

# %%
# 根据“逐日预测模型性能对比”选择最优模型，并用更丰富信息校准不确定集
import re, glob

# 1) 读取性能对比表，基于四项指标等权平均排名选最优
perf_files = sorted(glob.glob('**/*逐日预测模型性能对比*.xlsx', recursive=True))
best_model_name, best_prefix = None, None
perf_df = None
if perf_files:
    _tmp = _safe_read_excel(perf_files[0])
    if isinstance(_tmp, pd.DataFrame) and not _tmp.empty:
        perf_df = _tmp.copy()
        # 模型列名容错
        model_col = next((c for c in perf_df.columns if c.lower() in ('model', '模型')), None)
        if model_col is not None:
            # 指标列名容错
            def _col_like(keys):
                keys = [k.lower() for k in keys]
                for c in perf_df.columns:
                    lc = c.lower()
                    if any(k in lc for k in keys):
                        # 排除 WMAPE 与 MAPE 互相匹配
                        if 'mape' in keys and 'wmape' in lc:
                            continue
                        if 'mae' in keys and 'wmape' in lc:
                            continue
                        return c
                return None
            mae_c  = _col_like(['mae'])
            rmse_c = _col_like(['rmse'])
            mape_c = _col_like(['mape'])
            wmape_c= _col_like(['wmape'])
            metric_cols = [c for c in [mae_c, rmse_c, mape_c, wmape_c] if c is not None]
            if metric_cols:
                # 低者优，使用名次法等权平均
                ranks = perf_df[metric_cols].rank(ascending=True, method='min')
                perf_df['avg_rank'] = ranks.mean(axis=1)
                best_row = perf_df.sort_values('avg_rank').iloc[0]
                best_model_name = str(best_row[model_col])

# 从逐日详细结果中推断可用的模型前缀列表
def _available_prefixes(df: pd.DataFrame):
    pat = re.compile(r'^(.*)_prediction$')
    pref = []
    for c in df.columns:
        m = pat.match(c)
        if m:
            pref.append(m.group(1))
    return sorted(set(pref))

prefixes = _available_prefixes(forecast_df) if isinstance(forecast_df, pd.DataFrame) else []

# 名称规范化与匹配
syn_map = {
    'xgboost': 'XGBoost',
    'lightgbm': 'LightGBM',
    'catboost': 'CatBoost',
    'randomforest': 'RandomForest', 'random_forest': 'RandomForest',
    'linearregression': 'LinearRegression', 'linear': 'LinearRegression', 'ols': 'LinearRegression',
    'qrf': 'QRF', 'quantileforest': 'QRF', 'quantile_random_forest': 'QRF',
    'svr': 'SVR', 'lstm': 'LSTM',
}


def _normalize_name(name: str) -> str:
    key = re.sub(r'[^a-z]', '', str(name).lower())
    return syn_map.get(key, name)


def _match_prefix(best_name: str, candidates: list) -> str | None:
    if not best_name:
        return None
    nn = _normalize_name(best_name)
    # 直接同名
    if f"{nn}_prediction" in [f"{p}_prediction" for p in candidates]:
        return nn
    # 子串匹配
    for p in candidates:
        if nn.lower() in p.lower() or p.lower() in nn.lower():
            return p
    return None

best_prefix = _match_prefix(best_model_name, prefixes) or (prefixes[0] if prefixes else None)

# 2) 用最优模型的逐日信息构造 period 级 d_hat 与多种不确定半径
rho_ell2 = None
w_eps_L2 = None
w_radius_abs_scalar = None
beta_poly_vec = None

if best_prefix is not None and 'date' in forecast_df.columns and 'period' in forecast_df.columns:
    df = forecast_df.copy()

    def col_any(prefix: str, cand_suffix: list[str]):
        for suf in cand_suffix:
            c = f"{prefix}_{suf}"
            if c in df.columns:
                return c
        return None

    pred_c = col_any(best_prefix, ['prediction']) or ('Best_prediction' if 'Best_prediction' in df.columns else None)
    lo_c = col_any(best_prefix, ['band_lo']) or col_any(best_prefix, ['ellip_lo_90'])
    hi_c = col_any(best_prefix, ['band_hi']) or col_any(best_prefix, ['ellip_hi_90'])
    q90_c = col_any(best_prefix, ['roll_abs_q90_28d']) or ('best_roll_abs_q90_28d' if 'best_roll_abs_q90_28d' in df.columns else None)
    mae_c = col_any(best_prefix, ['roll_mae_28d']) or ('best_roll_mae_28d' if 'best_roll_mae_28d' in df.columns else None)
    std_c = col_any(best_prefix, ['roll_std_28d']) or ('best_roll_std_28d' if 'best_roll_std_28d' in df.columns else None)

    if pred_c is not None:
        z90 = 1.645  # 约 90% 分位常用系数
        df['_pred'] = pd.to_numeric(df[pred_c], errors='coerce')
        # 构造每日上下界
        if lo_c is not None and hi_c is not None:
            df['_lo'] = pd.to_numeric(df[lo_c], errors='coerce')
            df['_hi'] = pd.to_numeric(df[hi_c], errors='coerce')
        else:
            # 回退：用 q90 / mae / std 之一构造对称带
            mag = None
            for c in [q90_c, mae_c, std_c]:
                if c is not None:
                    mag = pd.to_numeric(df[c], errors='coerce')
                    if c == std_c:
                        mag = z90 * mag
                    break
            if mag is None:
                mag = delta_ratio * df['_pred']
            df['_lo'] = df['_pred'] - mag
            df['_hi'] = df['_pred'] + mag
        # 非负
        df['_lo'] = df['_lo'].clip(lower=0)

        # 标准差（用于 L2 椭球半径）
        if std_c is not None:
            df['_sigma'] = pd.to_numeric(df[std_c], errors='coerce')
        elif q90_c is not None:
            df['_sigma'] = pd.to_numeric(df[q90_c], errors='coerce') / z90
        elif mae_c is not None:
            df['_sigma'] = 1.25 * pd.to_numeric(df[mae_c], errors='coerce')
        else:
            df['_sigma'] = 0.2 * df['_pred']  # 兜底

        # Wasserstein-1 半径（逐日），优先用已给列
        if 'W1_radius_best_28d' in df.columns:
            df['_w1'] = pd.to_numeric(df['W1_radius_best_28d'], errors='coerce')
        else:
            # 回退：用 q90 作近似（1D 情况，可视作 L1 半径）
            df['_w1'] = (pd.to_numeric(df[q90_c], errors='coerce') if q90_c else 1.25 * pd.to_numeric(df.get(mae_c, pd.Series(0)), errors='coerce')).fillna(0)

        # 逐 period 聚合
        agg_pred = df.groupby('period')['_pred'].sum()
        agg_lo   = df.groupby('period')['_lo'].sum()
        agg_hi   = df.groupby('period')['_hi'].sum()
        # period 级“独立和”的标准差：根号和
        agg_sigma = df.groupby('period')['_sigma'].apply(lambda s: float(np.sqrt(np.nansum(np.square(s.to_numpy())))))
        # period 级 W1 半径：逐日半径求和的上界
        agg_w1 = df.groupby('period')['_w1'].sum()

        d_hat_best = agg_pred.to_numpy()
        box_half   = np.maximum(agg_hi.to_numpy() - d_hat_best, d_hat_best - agg_lo.to_numpy())
        # poly 的相邻差分界（守恒上界）：|z_k - z_{k-1}| ≤ box_k + box_{k-1}
        if len(box_half) > 1:
            beta_poly_vec = (box_half[:-1] + box_half[1:]).astype(float)
        else:
            beta_poly_vec = np.array([], dtype=float)

        # 椭球半径（L2）：z90 * ||sigma_period||_2
        rho_ell2 = float(1.645 * np.linalg.norm(agg_sigma.to_numpy(), ord=2))
        # Wasserstein 半径（L2 与 L∞ 两种）：
        w_eps_L2 = float(np.linalg.norm(agg_w1.to_numpy(), ord=2))
        w_radius_abs_scalar = float(np.max(agg_w1.to_numpy()))

        # 最终替换全局向量
        d_hat = d_hat_best.astype(float)
        delta = box_half.astype(float)
        K = len(d_hat)
        print(f"已根据性能对比选择最优模型: {best_model_name} -> 列前缀 {best_prefix}")
        print(f"box 半径(均值比例)≈ {float(np.mean(delta/np.maximum(d_hat,1e-6))):.3f}; 椭球半径(L2)= {rho_ell2:.2f}; W1(L2)= {w_eps_L2:.2f}")

# 将新口径导出（附带更多口径，便于复现）
try:
    out_df = pd.DataFrame({
        'period': np.arange(1, len(d_hat)+1),
        'd_hat': d_hat,
        'box_delta': delta,
    })
    if beta_poly_vec is not None and len(beta_poly_vec) == max(0, len(d_hat)-1):
        out_df['poly_beta_prev'] = pd.Series(beta_poly_vec).reindex(range(len(d_hat)), fill_value=np.nan)
    out_df.to_csv('uncertainty_14d_constructed.csv', index=False)
    print('已导出不确定集文件: uncertainty_14d_constructed.csv (含 box 与 poly 信息)')
except Exception as _e:
    print('导出不确定集文件失败:', _e)

# %%
# 修复与增强：
# - 依据“逐日预测模型性能对比”严格选最优模型
# - 避免变量名与成本参数 c/h/p 冲突
# - 用最优模型的日级 band/roll 指标校准 box/poly/ell2/w1，并覆盖 d_hat, delta
from typing import Optional
import re, glob

# 读取性能对比并返回最优模型名（MAE/RMSE/MAPE/WMAPE 等权平均排名，低者优）
def _read_best_model_from_perf() -> Optional[str]:
    files = sorted(glob.glob('**/*逐日预测模型性能对比*.xlsx', recursive=True))
    if not files:
        return None
    dfp = _safe_read_excel(files[0])
    if not isinstance(dfp, pd.DataFrame) or dfp.empty:
        return None
    # 模型列
    model_col = None
    for col in dfp.columns:
        s = str(col).lower()
        if ('model' in s) or ('模型' in str(col)):
            model_col = col; break
    if model_col is None:
        model_col = dfp.columns[0]
    # 指标列（容错）
    def _find(keys):
        keys = [k.lower() for k in keys]
        for col in dfp.columns:
            lc = str(col).lower()
            if any(k in lc for k in keys):
                if 'wmape' in lc and 'mape' in keys:
                    continue
                return col
        return None
    cols = [
        _find(['mae']),
        _find(['rmse']),
        _find(['mape']),
        _find(['wmape'])
    ]
    cols = [c for c in cols if c is not None]
    if not cols:
        return None
    ranks = dfp[cols].rank(ascending=True, method='average')
    dfp['avg_rank'] = ranks.mean(axis=1)
    best = dfp.sort_values('avg_rank', kind='mergesort').iloc[0]
    return str(best[model_col])

# 名称归一与前缀匹配
def _normalize(name: str) -> str:
    key = re.sub(r'[^a-z]', '', str(name).lower())
    mapping = {
        'xgboost':'XGBoost', 'lightgbm':'LightGBM', 'catboost':'CatBoost',
        'randomforest':'RandomForest', 'random_forest':'RandomForest',
        'linearregression':'LinearRegression','linear':'LinearRegression','ols':'LinearRegression',
        'qrf':'QRF','quantileforest':'QRF','quantilerandomforest':'QRF',
        'svr':'SVR','lstm':'LSTM','best':'Best'
    }
    return mapping.get(key, name)

def _all_prefixes(df: pd.DataFrame):
    return sorted(set(re.sub(r'_prediction$', '', c) for c in df.columns if str(c).endswith('_prediction')))

def _pick_prefix(best_name: Optional[str], df: pd.DataFrame) -> Optional[str]:
    prefs = _all_prefixes(df)
    if not prefs:
        return None
    if best_name:
        nn = _normalize(best_name)
        for p in prefs:
            if nn.lower() in p.lower() or p.lower() in nn.lower():
                return p
    # 回退优先级（没有性能表时）：QRF > XGBoost > LightGBM > RandomForest > LinearRegression > SVR > LSTM > Best
    pri = ['QRF','XGBoost','LightGBM','RandomForest','LinearRegression','SVR','LSTM','Best']
    for p in pri:
        if any(p.lower()==q.lower() for q in prefs):
            return p
    return prefs[0]

best_model_from_perf = _read_best_model_from_perf()

# 若 forecast_df 含逐日列，则据此重算 d_hat/delta；否则跳过
if isinstance(forecast_df, pd.DataFrame) and any(str(c).endswith('_prediction') for c in forecast_df.columns):
    pref = _pick_prefix(best_model_from_perf, forecast_df)
    df = forecast_df.copy()
    df['date'] = pd.to_datetime(df['date'], errors='coerce')
    if 'period' not in df.columns:
        df['period'] = ((df['date'] - df['date'].min()).dt.days // T_days) + 1

    def _col(prefix: str, suffixes):
        for sfx in suffixes:
            col = f"{prefix}_{sfx}"
            if col in df.columns:
                return col
        return None

    pred_col = _col(pref, ['prediction']) or ('Best_prediction' if 'Best_prediction' in df.columns else None)
    lo_col   = _col(pref, ['band_lo','ellip_lo_90'])
    hi_col   = _col(pref, ['band_hi','ellip_hi_90'])
    q90_col  = _col(pref, ['roll_abs_q90_28d'])
    mae_col  = _col(pref, ['roll_mae_28d'])
    std_col  = _col(pref, ['roll_std_28d'])

    if pred_col is not None:
        df['_pred'] = pd.to_numeric(df[pred_col], errors='coerce')
        z90 = 1.645
        if lo_col is not None and hi_col is not None:
            df['_lo'] = pd.to_numeric(df[lo_col], errors='coerce')
            df['_hi'] = pd.to_numeric(df[hi_col], errors='coerce')
        else:
            # 用候选指标构造对称带（注意变量名避免覆盖成本 c）
            mag = None
            for cand in [q90_col, mae_col, std_col]:
                if cand is None:
                    continue
                m = pd.to_numeric(df[cand], errors='coerce')
                if cand == std_col:
                    m = z90 * m
                mag = m
                break
            if mag is None:
                mag = delta_ratio * df['_pred']
            df['_lo'] = df['_pred'] - mag
            df['_hi'] = df['_pred'] + mag
        df['_lo'] = df['_lo'].clip(lower=0)

        # 日级 sigma，用于 L2 椭球半径
        if std_col is not None:
            df['_sigma'] = pd.to_numeric(df[std_col], errors='coerce')
        elif q90_col is not None:
            df['_sigma'] = pd.to_numeric(df[q90_col], errors='coerce') / z90
        elif mae_col is not None:
            df['_sigma'] = 1.25 * pd.to_numeric(df[mae_col], errors='coerce')
        else:
            df['_sigma'] = 0.2 * df['_pred']

        # 若有 W1 半径
        if 'W1_radius_best_28d' in df.columns:
            df['_w1'] = pd.to_numeric(df['W1_radius_best_28d'], errors='coerce')
        else:
            df['_w1'] = (pd.to_numeric(df[q90_col], errors='coerce') if q90_col else 1.25 * pd.to_numeric(df.get(mae_col, pd.Series(0)), errors='coerce')).fillna(0)

        # 聚合到 period
        agg_pred  = df.groupby('period')['_pred'].sum()
        agg_lo    = df.groupby('period')['_lo'].sum()
        agg_hi    = df.groupby('period')['_hi'].sum()
        agg_sigma = df.groupby('period')['_sigma'].apply(lambda s: float(np.sqrt(np.nansum(np.square(s.to_numpy())))))
        agg_w1    = df.groupby('period')['_w1'].sum()

        d_hat_new = agg_pred.to_numpy()
        delta_new = np.maximum(agg_hi.to_numpy() - d_hat_new, d_hat_new - agg_lo.to_numpy())

        # 覆盖全局（裁剪到规划期 K_periods）
        d_hat = np.array(d_hat_new[:K_periods], dtype=float)
        delta = np.array(delta_new[:K_periods], dtype=float)
        K = len(d_hat)

        # 计算并覆盖全局椭球/沃瑟斯坦半径（供后续模型使用）
        rho = float(1.645 * np.linalg.norm(agg_sigma.to_numpy()[:K], ord=2))
        rho1 = float(np.sqrt(K) * rho)
        w_eps = float(np.linalg.norm(agg_w1.to_numpy()[:K], ord=2))
        w_radius_abs = float(np.max(agg_w1.to_numpy()[:K]))
        
        # 注意：不重置成本参数，保持参数区设置；若需校验请见后续 _ensure_real 单元
        
        print(f"根据性能对比与逐日指标，采用最优模型: {best_model_from_perf} -> {pref}")
        print(f"box均值比例≈{float(np.mean(delta/np.maximum(d_hat,1e-6))):.3f} | ell2 ρ≈{rho:.2f} | W1(L2)≈{w_eps:.2f}")
else:
    # 仅修复成本参数可能被上文临时变量覆盖的问题
    try:
        float(c)
    except Exception:
        c = 0.0

# %%
# 防御性修正：PuLP 目标中使用的成本 c 必须为实数
# 若 c 被上面局部变量污染为 None，则重置为 0.0
def _ensure_real(x, default=0.0):
    try:
        xv = float(x)
        if np.isfinite(xv):
            return xv
        return float(default)
    except Exception:
        return float(default)

c = _ensure_real(c, 0.0)
h = _ensure_real(h, 1.0)
p = _ensure_real(p, 10.0)
f = _ensure_real(f, 100.0)
M = _ensure_real(M, 1e6)
print(f"成本参数校验: c={c}, h={h}, p={p}, f={f}")

# %%
# Static 版本：为 box / poly / ell1 / wass 构建鲁棒线性模型（与 AAR 对应）

def build_static_with_envelope(envelope_type='box'):
    assert envelope_type in ('box','poly','ell1','wass')
    mdl = pl.LpProblem(f"Static_{envelope_type}", pl.LpMinimize)

    vs = pl.LpVariable.dicts('v', list(range(1, K+1)), lowBound=0, upBound=1, cat=pl.LpBinary)
    us = pl.LpVariable.dicts('u', list(range(1, K+1)), lowBound=0)
    ys = pl.LpVariable.dicts('y', list(range(1, K+1)), lowBound=0)

    # u bounds
    for k in range(1, K+1):
        mdl += us[k] >= 0
        mdl += us[k] <= M * vs[k]

    cumd = np.cumsum(d_hat)

    # helper for poly dual bound with numeric c vector
    def _poly_sup(c_vec, k, prefix):
        c_dict = {t: float(c_vec[t-1]) for t in range(1, k+1)}
        return poly_dual_bound(mdl, c_dict, k, prefix)

    # choose R for ell1/wass
    R_ell1 = None
    try:
        R_ell1 = float(rho1)
    except Exception:
        R_ell1 = float(np.sqrt(K) * np.linalg.norm(delta, ord=2))
    R_wass = None
    try:
        R_wass = float(w_radius_abs)
    except Exception:
        R_wass = float(np.max(delta))

    for k in range(1, K+1):
        const_k = I1 + pl.lpSum(us[i] for i in range(1, k+1)) - float(cumd[k-1])
        # I_k 的 z 系数：仅 t=k 为 -1，其余为 0
        coeff = np.zeros(k)
        coeff[-1] = -1.0

        if envelope_type == 'box':
            # 仅 t=k 有贡献
            Sh = pl.LpVariable(f"Sh_{k}", lowBound=0)
            Sp = pl.LpVariable(f"Sp_{k}", lowBound=0)
            mdl += -Sh <= -h
            mdl += -h  <= Sh
            mdl += -Sp <= +p
            mdl += +p  <= Sp
            mdl += ys[k] >= h*const_k + delta[k-1]*Sh
            mdl += ys[k] >= p*(-const_k) + delta[k-1]*Sp
        elif envelope_type == 'poly':
            # sup_{F_k z ≤ g_k} (h*coeff · z)
            b1 = _poly_sup(h * coeff, k, prefix=f"sta_h_k{k}")
            b2 = _poly_sup(p * (-coeff), k, prefix=f"sta_p_k{k}")
            mdl += ys[k] >= h*const_k + b1
            mdl += ys[k] >= p*(-const_k) + b2
        elif envelope_type == 'ell1':
            # sup ≈ R * ||c||_∞；此处 ||h*coeff||_∞ = h，||p*(-coeff)||_∞ = p
            mdl += ys[k] >= h*const_k + R_ell1 * h
            mdl += ys[k] >= p*(-const_k) + R_ell1 * p
        elif envelope_type == 'wass':
            mdl += ys[k] >= h*const_k + R_wass * h
            mdl += ys[k] >= p*(-const_k) + R_wass * p

    Wv = pl.LpVariable('W', lowBound=0)
    mdl += Wv >= pl.lpSum(f*vs[k] + c*us[k] + ys[k] for k in range(1, K+1))
    mdl.setObjective(Wv)
    return mdl, dict(v=vs, u=us, y=ys)

# 构建并求解 Static 四种不确定集
models_static = {}
sol_static = {}
for name in ['box','poly','ell1','wass']:
    m, vars_ = build_static_with_envelope(name)
    models_static[name] = (m, vars_)
    st = m.solve(pl.PULP_CBC_CMD(msg=False, timeLimit=90))
    sol_static[name] = dict(status=pl.LpStatus[st], obj=float(pl.value(m.objective) or 0.0))

static_df = pd.DataFrame([dict(uncertainty=k, status=v['status'], worst_obj=v['obj']) for k,v in sol_static.items()])
display(static_df)

# %%
# 统一评估：AAR vs Static（各自配四种不确定集）

# 复用 evaluate/affine_policy_orders/simulate_trajectory 定义

def _extract_pulp_solution(vars_, is_affine: bool):
    if is_affine:
        v = np.array([pl.value(vars_['v'][k]) for k in range(1, K+1)])
        u0 = np.array([pl.value(vars_['u0'][k]) for k in range(1, K+1)])
        A = np.zeros((K,K))
        for k in range(1, K+1):
            for t in range(1, k):
                A[k-1,t-1] = pl.value(vars_['A'][(k,t)]) if (k,t) in vars_['A'] else 0.0
        return v, u0, A
    else:
        v = np.array([pl.value(vars_['v'][k]) for k in range(1, K+1)])
        u = np.array([pl.value(vars_['u'][k]) for k in range(1, K+1)])
        return v, u, None

# 汇总 AAR
aar_rows = []
for name, (mdl, vars_) in models.items():
    v_, u0_, A_ = _extract_pulp_solution(vars_, is_affine=True)
    ev = evaluate(u0_, A_, v_, d_hat, delta, I1, (f,c,h,p), num_mc=200, seed=2025)
    aar_rows.append(dict(
        method=f'AAR-{name}',
        worst_obj=float(pl.value(mdl.objective) or 0.0),
        nominal_total=ev['nominal']['total'],
        nominal_service=ev['nominal']['service_rate'],
        MC_mean_total=ev['mc']['total']['mean'],
        MC_std_total=ev['mc']['total']['std'],
        MC_VaR95=ev['mc']['VaR95'],
        MC_CVaR95=ev['mc']['CVaR95'],
        MC_mean_service=ev['mc']['service']['mean'],
    ))

# 汇总 Static
sta_rows = []
for name, (mdl, vars_) in models_static.items():
    v_, u_, _ = _extract_pulp_solution(vars_, is_affine=False)
    ev = evaluate(u_, None, v_, d_hat, delta, I1, (f,c,h,p), num_mc=200, seed=2026)
    sta_rows.append(dict(
        method=f'Static-{name}',
        worst_obj=float(pl.value(mdl.objective) or 0.0),
        nominal_total=ev['nominal']['total'],
        nominal_service=ev['nominal']['service_rate'],
        MC_mean_total=ev['mc']['total']['mean'],
        MC_std_total=ev['mc']['total']['std'],
        MC_VaR95=ev['mc']['VaR95'],
        MC_CVaR95=ev['mc']['CVaR95'],
        MC_mean_service=ev['mc']['service']['mean'],
    ))

compare_df = pd.DataFrame(aar_rows + sta_rows)
display(compare_df.sort_values(['method']).reset_index(drop=True))

# %%
# 可选：用跨模型离散度对不确定集进行微调（非回退）
# 目标：基于 LSTM/QRF/RandomForest 的离散度调整每期 gamma_k，对 box/poly/ell2/w1 做比例放缩
import numpy as np
import pandas as pd

# 配置
adj_models = ['LSTM', 'QRF', 'RandomForest']
dispersion_measure = 'range_ratio'  # 'range_ratio' | 'std_ratio'
tau_lo, tau_hi = 0.10, 0.30          # 低/高离散阈值（相对 d_hat）
gamma_lo, gamma_hi = 0.95, 1.25      # 缩紧/放宽上下界

# 构造期级多模型预测矩阵
def _aggregate_models_period(df: pd.DataFrame, models: list[str]) -> pd.DataFrame:
    need = []
    for m in models:
        col = f"{m}_prediction"
        if col in df.columns:
            need.append(col)
    if not need:
        return pd.DataFrame()
    tmp = df[['period'] + need].copy()
    agg = tmp.groupby('period')[need].sum(min_count=1)
    agg.columns = [c.replace('_prediction','') for c in agg.columns]
    return agg.reset_index()

# 保障 period 存在
if isinstance(forecast_df, pd.DataFrame) and 'date' in forecast_df.columns:
    if 'period' not in forecast_df.columns:
        forecast_df['period'] = ((pd.to_datetime(forecast_df['date']) - pd.to_datetime(forecast_df['date']).min()).dt.days // T_days) + 1

Gamma = np.ones_like(d_hat, dtype=float)
if isinstance(forecast_df, pd.DataFrame):
    agg_tbl = _aggregate_models_period(forecast_df, adj_models)
    if not agg_tbl.empty:
        merged = pd.DataFrame({'period': np.arange(1, len(d_hat)+1), 'd_hat': d_hat}).merge(agg_tbl, on='period', how='left')
        ratios = []
        for _, row in merged.iterrows():
            values = [row[m] for m in adj_models if m in merged.columns]
            values = [float(v) for v in values if pd.notna(v)]
            if len(values) >= 2:
                if dispersion_measure == 'range_ratio':
                    disp = (max(values) - min(values)) / max(float(row['d_hat']), 1e-6)
                else:
                    mu = np.mean(values)
                    sd = float(np.std(values))
                    disp = sd / max(float(row['d_hat']), 1e-6)
            else:
                disp = np.nan
            ratios.append(disp)
        ratios = np.array(ratios, dtype=float)
        # 计算 gamma：线性插值 + 截断
        Gamma = np.ones_like(d_hat, dtype=float)
        for k in range(len(d_hat)):
            r = ratios[k]
            if not np.isfinite(r):
                Gamma[k] = 1.0
            elif r <= tau_lo:
                Gamma[k] = gamma_lo
            elif r >= tau_hi:
                Gamma[k] = gamma_hi
            else:
                t = (r - tau_lo) / (tau_hi - tau_lo)
                Gamma[k] = gamma_lo + t*(gamma_hi - gamma_lo)

# 应用放缩到 box 与 poly
box_delta_base = delta.copy()
delta = (delta * Gamma).astype(float)
if 'poly_beta_prev' in locals() and isinstance(poly_beta_prev, np.ndarray) and len(poly_beta_prev) == max(0, len(delta)-1):
    poly_beta_prev = (Gamma[:-1]*box_delta_base[:-1] + Gamma[1:]*box_delta_base[1:]).astype(float)
else:
    poly_beta_prev = (delta[:-1] + delta[1:]).astype(float)

# 近似放缩椭球与 W1 半径（RMS/Max 缩放）
gamma_rms = float(np.sqrt(np.mean(np.square(Gamma))))
gamma_max = float(np.max(Gamma))
try:
    rho = float(rho) * gamma_rms
    rho1 = float(np.sqrt(len(d_hat)) * rho)
except Exception:
    pass
try:
    w_eps = float(w_eps) * gamma_rms
    w_radius_abs = float(w_radius_abs) * gamma_max
except Exception:
    pass

print('离散度微调完成: gamma范围=', float(Gamma.min()), '→', float(Gamma.max()))

# 更新导出文件（追加 gamma 列与经调后的 delta）
try:
    out_df = pd.DataFrame({'period': np.arange(1, len(d_hat)+1), 'd_hat': d_hat, 'box_delta': delta, 'gamma_dispersion': Gamma})
    out_df['poly_beta_prev'] = pd.Series(poly_beta_prev).reindex(range(len(d_hat)), fill_value=np.nan)
    out_df.to_csv('uncertainty_14d_constructed.csv', index=False)
    print('已更新 uncertainty_14d_constructed.csv（含 gamma 与微调后的 box/poly）。')
except Exception as _e:
    print('导出更新失败:', _e)

# %%
# AAR Final2：单一仿射 y_k + 对偶鲁棒包络 + 仿射 u_k
m_aar = pl.LpProblem("AAR_Final2", pl.LpMinimize)

v = pl.LpVariable.dicts('v', list(range(1, K+1)), lowBound=0, upBound=1, cat=pl.LpBinary)
u0 = pl.LpVariable.dicts('u0', list(range(1, K+1)), lowBound=0)
A = {}
for k in range(1, K+1):
    for t in range(1, k):
        A[(k,t)] = pl.LpVariable(f"a_{k}_{t}", lowBound=None)

# y(d) = y0 + sum_{t<=k} Y_{k,t} d_t
y0 = pl.LpVariable.dicts('y0', list(range(1, K+1)), lowBound=0)
Y = {}
for k in range(1, K+1):
    for t in range(1, k+1):
        Y[(k,t)] = pl.LpVariable(f"Y_{k}_{t}", lowBound=None)

# 包络松弛变量
Rh = {}; Rp = {}
for k in range(1, K+1):
    for t in range(1, k+1):
        Rh[(k,t)] = pl.LpVariable(f"Rh_{k}_{t}", lowBound=0)
        Rp[(k,t)] = pl.LpVariable(f"Rp_{k}_{t}", lowBound=0)

# 目标中的 z 系数包络（仅来自 c*u 仿射项）
W = pl.LpVariable('W', lowBound=0)
n = pl.LpVariable.dicts('n', list(range(1, K+1)), lowBound=0)

# 仿射 u 的鲁棒上下界
x = {}
for k in range(1, K+1):
    for t in range(1, k):
        x[(k,t)] = pl.LpVariable(f"x_{k}_{t}", lowBound=0)
        m_aar += -x[(k,t)] <= A[(k,t)]
        m_aar += A[(k,t)] <= x[(k,t)]
    if k == 1:
        m_aar += u0[1] >= 0
        m_aar += u0[1] <= M * v[1]
    else:
        m_aar += u0[k] - pl.lpSum(delta[t-1]*x[(k,t)] for t in range(1,k)) >= 0
        m_aar += u0[k] + pl.lpSum(delta[t-1]*x[(k,t)] for t in range(1,k)) <= M * v[k]

# I_k(z) 的常数项与 z 系数
cum_dhat = np.cumsum(d_hat)
for k in range(1, K+1):
    const_k = I1 + pl.lpSum(u0[i] for i in range(1, k+1)) - cum_dhat[k-1]
    for t in range(1, k+1):
        coeff = pl.lpSum(A[(i,t)] for i in range(max(t+1,2), k+1) if (i,t) in A)
        if t == k:
            coeff = coeff + (-1)
        # y ≥ h·I 的包络
        m_aar += -Rh[(k,t)] <= (Y[(k,t)] - h*coeff)
        m_aar += (Y[(k,t)] - h*coeff) <= Rh[(k,t)]
        # y ≥ p·(-I) 的包络
        m_aar += -Rp[(k,t)] <= (-p*coeff - Y[(k,t)])
        m_aar += (-p*coeff - Y[(k,t)]) <= Rp[(k,t)]
    y_const = y0[k] + pl.lpSum(Y[(k,t)]*d_hat[t-1] for t in range(1, k+1))
    m_aar += y_const >= h*const_k + pl.lpSum(delta[t-1]*Rh[(k,t)] for t in range(1, k+1))
    m_aar += y_const >= p*(-const_k) + pl.lpSum(delta[t-1]*Rp[(k,t)] for t in range(1, k+1))

# 目标中的 z 系数仅来自 c*u 仿射项
for t in range(1, K+1):
    coeff_t_obj = pl.lpSum(A[(i,t)] for i in range(max(t+1,2), K+1) if (i,t) in A)
    m_aar += -n[t] <= c * coeff_t_obj
    m_aar += c * coeff_t_obj <= n[t]

# 目标
m_aar += W
m_aar += W >= pl.lpSum(f*v[k] + c*u0[k] + (y0[k] + pl.lpSum(Y[(k,t)]*d_hat[t-1] for t in range(1, k+1))) for k in range(1, K+1)) \
               + pl.lpSum(delta[t-1]*n[t] for t in range(1, K+1))

print("AAR Final2 built. Vars:", len(m_aar.variables()))

# %%
# Static 基线：u 静态，y 静态（不仿射）
m_sta = pl.LpProblem("Static_Robust_Final", pl.LpMinimize)

vs = pl.LpVariable.dicts('v', list(range(1, K+1)), lowBound=0, upBound=1, cat=pl.LpBinary)
us = pl.LpVariable.dicts('u', list(range(1, K+1)), lowBound=0)
ys = pl.LpVariable.dicts('y', list(range(1, K+1)), lowBound=0)

Sh = {}; Sp = {}
for k in range(1, K+1):
    for t in range(1, k+1):
        Sh[(k,t)] = pl.LpVariable(f"Sh_{k}_{t}", lowBound=0)
        Sp[(k,t)] = pl.LpVariable(f"Sp_{k}_{t}", lowBound=0)

W_s = pl.LpVariable('W', lowBound=0)

for k in range(1, K+1):
    m_sta += us[k] >= 0
    m_sta += us[k] <= M * vs[k]

cum_dhat = np.cumsum(d_hat)
for k in range(1, K+1):
    const_k = I1 + pl.lpSum(us[i] for i in range(1, k+1)) - cum_dhat[k-1]
    # I 的 z 系数只有 t=k 为 -1
    m_sta += -Sh[(k,k)] <= -h
    m_sta += -h <= Sh[(k,k)]
    m_sta += -Sp[(k,k)] <= +p
    m_sta += +p <= Sp[(k,k)]
    m_sta += ys[k] >= h*const_k + delta[k-1]*Sh[(k,k)]
    m_sta += ys[k] >= p*(-const_k) + delta[k-1]*Sp[(k,k)]

m_sta += W_s
m_sta += W_s >= pl.lpSum(f*vs[k] + c*us[k] + ys[k] for k in range(1, K+1))

print("Static baseline built. Vars:", len(m_sta.variables()))

# %%
# 求解两模型
res_aar = m_aar.solve(pl.PULP_CBC_CMD(msg=False, timeLimit=180))
res_sta = m_sta.solve(pl.PULP_CBC_CMD(msg=False, timeLimit=120))
print("AAR:", pl.LpStatus[res_aar])
print("Static:", pl.LpStatus[res_sta])

v_sol = np.array([pl.value(v[k]) for k in range(1, K+1)])
u0_sol = np.array([pl.value(u0[k]) for k in range(1, K+1)])
A_mat = np.zeros((K,K))
for k in range(1, K+1):
    for t in range(1, k):
        A_mat[k-1, t-1] = pl.value(A[(k,t)]) if (k,t) in A else 0.0

y0_sol = np.array([pl.value(y0[k]) for k in range(1, K+1)])
Y_mat = np.zeros((K,K))
for k in range(1, K+1):
    for t in range(1, k+1):
        Y_mat[k-1, t-1] = pl.value(Y[(k,t)]) if (k,t) in Y else 0.0

vs_sol = np.array([pl.value(vs[k]) for k in range(1, K+1)])
us_sol = np.array([pl.value(us[k]) for k in range(1, K+1)])
ys_sol = np.array([pl.value(ys[k]) for k in range(1, K+1)])

# %%
# 评估与对比（保留完整指标）

def affine_policy_orders(u0_vec, A_mat, z_vec):
    K = len(u0_vec)
    u = np.array(u0_vec, dtype=float).copy()
    if A_mat is None:
        return np.maximum(u, 0.0)
    for k in range(1, K):
        u[k] = u0_vec[k] + float(np.dot(A_mat[k, :k], z_vec[:k]))
    return np.maximum(u, 0.0)


def simulate_trajectory(u_vec, v_vec, d_hat_vec, z_vec, I1, costs):
    f, c, h, p = costs
    K = len(u_vec)
    I = np.zeros(K)
    d_real = d_hat_vec + z_vec

    I[0] = I1 + u_vec[0] - d_real[0]
    for k in range(1, K):
        I[k] = I[k-1] + u_vec[k] - d_real[k]

    y_pos = np.maximum(I, 0)
    y_neg = np.maximum(-I, 0)

    fixed = f * np.sum((v_vec > 0.5).astype(int))
    variable = c * np.sum(u_vec)
    holding = h * np.sum(y_pos)
    penalty = p * np.sum(y_neg)
    total = fixed + variable + holding + penalty

    service_rate = np.mean(I >= 0)
    stockouts = int(np.sum(I < 0))

    return dict(total=total, fixed=fixed, variable=variable, holding=holding, penalty=penalty,
                service_rate=service_rate, stockouts=stockouts, I_series=I)


def evaluate(u0_vec, A_mat, v_vec, d_hat_vec, delta_vec, I1, costs, num_mc=300, seed=2025):
    rng = np.random.default_rng(seed)
    z0 = np.zeros_like(delta_vec)
    nom = simulate_trajectory(affine_policy_orders(u0_vec, A_mat, z0), v_vec, d_hat_vec, z0, I1, costs)

    z_plus = +delta_vec
    z_minus = -delta_vec
    plus = simulate_trajectory(affine_policy_orders(u0_vec, A_mat, z_plus), v_vec, d_hat_vec, z_plus, I1, costs)
    minus = simulate_trajectory(affine_policy_orders(u0_vec, A_mat, z_minus), v_vec, d_hat_vec, z_minus, I1, costs)

    mc = []
    for _ in range(num_mc):
        z = rng.uniform(low=-delta_vec, high=+delta_vec)
        mc.append(simulate_trajectory(affine_policy_orders(u0_vec, A_mat, z), v_vec, d_hat_vec, z, I1, costs))

    def agg(key):
        arr = np.array([it[key] for it in mc])
        return dict(mean=float(arr.mean()), std=float(arr.std()), p90=float(np.quantile(arr,0.9)),
                    p95=float(np.quantile(arr,0.95)), p99=float(np.quantile(arr,0.99)))

    totals = np.array([it['total'] for it in mc])
    var95 = float(np.quantile(totals, 0.95))
    cvar95 = float(totals[totals>=var95].mean())

    return dict(nominal=nom, plus=plus, minus=minus,
                mc=dict(total=agg('total'), service=agg('service_rate'), stockouts=agg('stockouts'),
                        VaR95=var95, CVaR95=cvar95))

costs_tuple = (f, c, h, p)

# AAR 评估（u 仿射）；Static 评估（u 静态）
aar_eval = evaluate(u0_sol, A_mat, v_sol, d_hat, delta, I1, costs_tuple)
sta_eval = evaluate(us_sol, None, vs_sol, d_hat, delta, I1, costs_tuple)

summary = pd.DataFrame([
    dict(method='AAR', nominal_total=aar_eval['nominal']['total'], nominal_service=aar_eval['nominal']['service_rate'],
         worst_plus_total=aar_eval['plus']['total'], worst_minus_total=aar_eval['minus']['total'],
         MC_mean_total=aar_eval['mc']['total']['mean'], MC_std_total=aar_eval['mc']['total']['std'],
         MC_VaR95=aar_eval['mc']['VaR95'], MC_CVaR95=aar_eval['mc']['CVaR95'],
         MC_mean_service=aar_eval['mc']['service']['mean']),
    dict(method='Static', nominal_total=sta_eval['nominal']['total'], nominal_service=sta_eval['nominal']['service_rate'],
         worst_plus_total=sta_eval['plus']['total'], worst_minus_total=sta_eval['minus']['total'],
         MC_mean_total=sta_eval['mc']['total']['mean'], MC_std_total=sta_eval['mc']['total']['std'],
         MC_VaR95=sta_eval['mc']['VaR95'], MC_CVaR95=sta_eval['mc']['CVaR95'],
         MC_mean_service=sta_eval['mc']['service']['mean'])
])
summary

# %%
# 名义场景成本分解对比
nom_breakdown = pd.DataFrame([
    dict(method='AAR', fixed=aar_eval['nominal']['fixed'], variable=aar_eval['nominal']['variable'],
         holding=aar_eval['nominal']['holding'], penalty=aar_eval['nominal']['penalty'], total=aar_eval['nominal']['total']),
    dict(method='Static', fixed=sta_eval['nominal']['fixed'], variable=sta_eval['nominal']['variable'],
         holding=sta_eval['nominal']['holding'], penalty=sta_eval['nominal']['penalty'], total=sta_eval['nominal']['total'])
])
nom_breakdown

# %%
# 随机场景总成本分布对比
rng = np.random.default_rng(2026)
N = 400
AAR_totals, STA_totals = [], []
for _ in range(N):
    z = rng.uniform(low=-delta, high=+delta)
    AAR_totals.append(simulate_trajectory(affine_policy_orders(u0_sol, A_mat, z), v_sol, d_hat, z, I1, costs_tuple)['total'])
    STA_totals.append(simulate_trajectory(affine_policy_orders(us_sol, None, z), vs_sol, d_hat, z, I1, costs_tuple)['total'])

plt.figure(figsize=(10,5))
plt.hist(AAR_totals, bins=24, alpha=0.6, label='AAR total')
plt.hist(STA_totals, bins=24, alpha=0.6, label='Static total')
plt.axvline(np.mean(AAR_totals), color='C0', linestyle='--', label='AAR mean')
plt.axvline(np.mean(STA_totals), color='C1', linestyle='--', label='Static mean')
plt.title('随机Box场景总成本分布（AAR vs Static）')
plt.legend()
plt.show()

# %%
# 若原始文件包含真实 demand，则进行“历史实现”评估
has_real = 'demand' in forecast_df.columns
if has_real:
    agg_real = forecast_df.groupby('period', as_index=False)['demand'].sum().head(K)
    d_real = agg_real['demand'].to_numpy()
    # 历史实现的偏差
    z_hist = d_real - d_hat

    # AAR 历史评估
    aar_hist = simulate_trajectory(affine_policy_orders(u0_sol, A_mat, z_hist), v_sol, d_hat, z_hist, I1, costs_tuple)
    # Static 历史评估
    sta_hist = simulate_trajectory(affine_policy_orders(us_sol, None, z_hist), vs_sol, d_hat, z_hist, I1, costs_tuple)

    summary_hist = pd.DataFrame([
        dict(method='AAR', historical_total=aar_hist['total'], historical_service=aar_hist['service_rate'],
             historical_stockouts=aar_hist['stockouts']),
        dict(method='Static', historical_total=sta_hist['total'], historical_service=sta_hist['service_rate'],
             historical_stockouts=sta_hist['stockouts'])
    ])
    summary_hist
else:
    print('未发现真实 demand 列；跳过历史实现评估（仅基于预测与不确定集评估）。')

# %% [markdown]
# ## 扩展不确定集与效果对比
# - 多面体集（Polyhedral）：引入差分平滑与上下界共同定义的多面体 U = {z | F z ≤ g}，鲁棒包络通过对偶变量 λ（F^T λ = c, λ≥0）实现。
# - 椭球集（Ellipsoidal, 近似）：以 L2 范数上界的近似多面体化（L1 上界）替代，得到保守但线性的近似模型。
# - Wasserstein 集（近似）：对线性函数的 DRO 上界采用“经验均值 + 半径×对偶范数”近似（无历史样本时均值为0）。

# %%
# 1) 多面体不确定集：F z ≤ g 的鲁棒线化（因果版）
# 约束形式：|z_k| ≤ δ_k；以及相邻差分 |z_k − z_{k-1}| ≤ β（可选）。
# 为保持信息因果性：在第 k 期相关的鲁棒约束只使用 z_1..z_k（y_k）与 z_1..z_{k-1}（u_k）。

beta_ratio = 0.3
beta = beta_ratio * np.mean(delta) if K > 1 else 0.0

# 生成全局 F, g（用于构造分期 F_k）
I = np.eye(K)
rows = []
bs = []
rows.append(+I); bs.append(delta)     # +I z ≤ δ
rows.append(-I); bs.append(delta)     # -I z ≤ δ
if K > 1:
    D = np.zeros((K-1, K))
    for k in range(1, K):
        D[k-1, k] = 1
        D[k-1, k-1] = -1
    rows.append(+D); bs.append(beta*np.ones(K-1))  #  z_k - z_{k-1} ≤ β
    rows.append(-D); bs.append(beta*np.ones(K-1))  # -z_k + z_{k-1} ≤ β
F_full = np.vstack(rows)
g_full = np.concatenate(bs)

# 提取分期（因果）F_k, g_k：仅保留在列索引 ≤ k 有非零项的行，并截取前 k 列

def stage_Fg(k):
    mask = np.max(np.abs(F_full[:, :k]), axis=1) > 0  # 行在前k列有非零
    Fk = F_full[mask, :k]
    gk = g_full[mask]
    return Fk, gk

# 创建多面体对偶上界：max_{F_k z≤g_k} c(1..k)^T z = min_{λ≥0} g_k^T λ s.t. F_k^T λ = c
# 支持 c 为“变量线性表达”的情形（与 a、Y 联动）

def poly_dual_bound(mdl, c_dict, k, prefix):
    # c_dict: 映射 j->(线性表达) 表示 c_j, j=1..k
    Fk, gk = stage_Fg(k)
    lam = pl.LpVariable.dicts(f"lam_{prefix}_k{k}", list(range(Fk.shape[0])), lowBound=0)
    # Fk^T lam == c
    for j in range(k):
        mdl += pl.lpSum(Fk[i, j]*lam[i] for i in range(Fk.shape[0])) == c_dict.get(j+1, 0)
    return pl.lpSum(gk[i]*lam[i] for i in range(Fk.shape[0]))

# %%
# 2) 椭球集近似（L2 -> L1 近似）：||z||_2 ≤ ρ 以 ∑ |z_k| ≤ ρ' 近似（线性可解）
rho_ratio = 0.8
rho = rho_ratio * np.linalg.norm(delta, ord=2)
# L1 上界：∑ |z_k| ≤ ρ'，保守设 ρ' = sqrt(K)*rho（Cauchy 上界），用于线性近似
rho1 = np.sqrt(K) * rho

# 对 c^T z 的最坏值近似为 rho1 * ||c||_∞（取 L∞ 对偶）
def ellipsoidal_L1_envelope(c_vec):
    return rho1 * float(np.max(np.abs(c_vec)))

# %%
# 3) Wasserstein DRO 近似（线性函数）：E[c^T z] + radius * ||c||_*
# 若无历史样本，E[z]=0，取 radius = w_radius * mean(delta)
w_radius = 0.5
w_radius_abs = w_radius * float(np.mean(delta))

def wasserstein_abs_envelope(c_vec):
    # 使用 L1/L∞ 对偶简化：radius * ||c||_∞
    return w_radius_abs * float(np.max(np.abs(c_vec)))

# %%
# 构建对比：仅替换 y 包络与目标中 z 系数上界项（保持 AAR 的 u 仿射与 y 仿射结构）

def build_aar_with_envelope(envelope_type='box'):
    # envelope_type: 'box'|'poly'|'ell1'|'wass'
    mdl = pl.LpProblem(f"AAR_{envelope_type}", pl.LpMinimize)
    v_ = pl.LpVariable.dicts('v', list(range(1, K+1)), 0, 1, cat=pl.LpBinary)
    u0_ = pl.LpVariable.dicts('u0', list(range(1, K+1)), lowBound=0)
    A_ = {}
    for k in range(1, K+1):
        for t in range(1, k):
            A_[(k,t)] = pl.LpVariable(f"a_{k}_{t}", lowBound=None)
    y0_ = pl.LpVariable.dicts('y0', list(range(1, K+1)), lowBound=0)
    Y_ = {}
    for k in range(1, K+1):
        for t in range(1, k+1):
            Y_[(k,t)] = pl.LpVariable(f"Y_{k}_{t}", lowBound=None)

    # 松弛
    R1 = {}; R2 = {}
    for k in range(1, K+1):
        for t in range(1, k+1):
            R1[(k,t)] = pl.LpVariable(f"R1_{k}_{t}", lowBound=0)
            R2[(k,t)] = pl.LpVariable(f"R2_{k}_{t}", lowBound=0)

    W_ = pl.LpVariable('W', lowBound=0)

    cumd = np.cumsum(d_hat)

    # u 鲁棒上下界（按不确定集分别处理）
    for k in range(1, K+1):
        if k == 1:
            mdl += u0_[1] >= 0
            mdl += u0_[1] <= M * v_[1]
        else:
            if envelope_type == 'box':
                # sup_{|z_t|≤δ_t} (±∑_{t<k} a_{k,t} z_t) = ∑ δ_t |a_{k,t}|
                x_ = {t: pl.LpVariable(f"x_{k}_{t}", lowBound=0) for t in range(1,k)}
                for t in range(1,k):
                    mdl += -x_[t] <= A_[(k,t)]
                    mdl +=  A_[(k,t)] <= x_[t]
                mdl += u0_[k] - pl.lpSum(delta[t-1]*x_[t] for t in range(1,k)) >= 0
                mdl += u0_[k] + pl.lpSum(delta[t-1]*x_[t] for t in range(1,k)) <= M * v_[k]
            elif envelope_type == 'poly':
                # sup_{F_{k-1} z≤g_{k-1}} (±∑_{t<k} a_{k,t} z_t) via dual
                # positive
                c_pos = {t: A_[(k,t)] for t in range(1,k)}
                b_pos = poly_dual_bound(mdl, c_pos, k-1, prefix=f"u_pos_k{k}")
                # negative
                c_neg = {t: -A_[(k,t)] for t in range(1,k)}
                b_neg = poly_dual_bound(mdl, c_neg, k-1, prefix=f"u_neg_k{k}")
                mdl += u0_[k] - b_neg >= 0
                mdl += u0_[k] + b_pos <= M * v_[k]
            elif envelope_type == 'ell1':
                # L1 approx: sup ≈ ∑ w_t |a_{k,t}|
                x_ = {t: pl.LpVariable(f"x_{k}_{t}", lowBound=0) for t in range(1,k)}
                for t in range(1,k):
                    mdl += -x_[t] <= A_[(k,t)]
                    mdl +=  A_[(k,t)] <= x_[t]
                w = {t: ellipsoidal_L1_envelope(np.eye(K)[t-1]) for t in range(1,k)}
                mdl += u0_[k] - pl.lpSum(w[t]*x_[t] for t in range(1,k)) >= 0
                mdl += u0_[k] + pl.lpSum(w[t]*x_[t] for t in range(1,k)) <= M * v_[k]
            elif envelope_type == 'wass':
                x_ = {t: pl.LpVariable(f"x_{k}_{t}", lowBound=0) for t in range(1,k)}
                for t in range(1,k):
                    mdl += -x_[t] <= A_[(k,t)]
                    mdl +=  A_[(k,t)] <= x_[t]
                w = {t: wasserstein_abs_envelope(np.eye(K)[t-1]) for t in range(1,k)}
                mdl += u0_[k] - pl.lpSum(w[t]*x_[t] for t in range(1,k)) >= 0
                mdl += u0_[k] + pl.lpSum(w[t]*x_[t] for t in range(1,k)) <= M * v_[k]

    # y 包络
    for k in range(1, K+1):
        const_k = I1 + pl.lpSum(u0_[i] for i in range(1, k+1)) - cumd[k-1]
        # 构造 coeff_{k,t}
        coeff = {}
        for t in range(1, k+1):
            coeff[t] = pl.lpSum(A_[(i,t)] for i in range(max(t+1,2), k+1) if (i,t) in A_)
            if t == k:
                coeff[t] = coeff[t] + (-1)
        if envelope_type == 'poly':
            # y_const ≥ h*const + sup_{F_k z≤g_k} ⟨Y−h*coeff, z⟩
            c1 = {t: (Y_[(k,t)] - h*coeff[t]) for t in range(1,k+1)}
            b1 = poly_dual_bound(mdl, c1, k, prefix=f"yh")
            mdl += (y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1,k+1))) >= h*const_k + b1
            # y_const ≥ p*(−const) + sup ⟨−p*coeff − Y, z⟩
            c2 = {t: (-p*coeff[t] - Y_[(k,t)]) for t in range(1,k+1)}
            b2 = poly_dual_bound(mdl, c2, k, prefix=f"yp")
            mdl += (y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1,k+1))) >= p*(-const_k) + b2
        else:
            for t in range(1, k+1):
                mdl += -R1[(k,t)] <= (Y_[(k,t)] - h*coeff[t])
                mdl += (Y_[(k,t)] - h*coeff[t]) <= R1[(k,t)]
                mdl += -R2[(k,t)] <= (-p*coeff[t] - Y_[(k,t)])
                mdl += (-p*coeff[t] - Y_[(k,t)]) <= R2[(k,t)]
            mdl += (y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1,k+1))) \
                   >= h*const_k + pl.lpSum(delta[t-1]*R1[(k,t)] for t in range(1,k+1))
            mdl += (y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1,k+1))) \
                   >= p*(-const_k) + pl.lpSum(delta[t-1]*R2[(k,t)] for t in range(1,k+1))

    # 目标 z 部分
    if envelope_type == 'poly':
        poly_terms = []
        for t in range(1, K+1):
            c_dict = {t: c * pl.lpSum(A_[(i,t)] for i in range(max(t+1,2), K+1) if (i,t) in A_)}
            poly_terms.append(poly_dual_bound(mdl, c_dict, t, prefix=f"obj_t{t}"))
        mdl += W_ >= pl.lpSum(f*v_[k] + c*u0_[k] + (y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1,k+1))) for k in range(1, K+1)) \
                     + pl.lpSum(poly_terms)
    elif envelope_type == 'box':
        mdl += W_ >= pl.lpSum(f*v_[k] + c*u0_[k] + (y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1,k+1))) for k in range(1, K+1)) \
                     + pl.lpSum(delta[t-1]*pl.lpSum(A_[(i,t)] for i in range(max(t+1,2), K+1) if (i,t) in A_) for t in range(1, K+1))
    elif envelope_type == 'ell1':
        env = pl.lpSum(ellipsoidal_L1_envelope(np.eye(K)[t-1]) * pl.lpSum(A_[(i,t)] for i in range(max(t+1,2), K+1) if (i,t) in A_) for t in range(1, K+1))
        mdl += W_ >= pl.lpSum(f*v_[k] + c*u0_[k] + (y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1,k+1))) for k in range(1, K+1)) + env
    elif envelope_type == 'wass':
        env = pl.lpSum(wasserstein_abs_envelope(np.eye(K)[t-1]) * pl.lpSum(A_[(i,t)] for i in range(max(t+1,2), K+1) if (i,t) in A_) for t in range(1, K+1))
        mdl += W_ >= pl.lpSum(f*v_[k] + c*u0_[k] + (y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1,k+1))) for k in range(1, K+1)) + env

    mdl.setObjective(W_)
    return mdl, dict(v=v_, u0=u0_, A=A_, y0=y0_, Y=Y_)

# %%
# 修正版：统一对偶风格 + 因果结构的 ell1/wass 线性近似（基于 L1 集，对偶 ∥c∥_∞）
# - u 界：env = R * m_u，m_u ≥ ± a_{k,t}, t<k
# - y 包络：env = R * m_y，m_y ≥ ±(Y_{k,t} − h·coeff_{k,t}) 与 ±(−p·coeff_{k,t} − Y_{k,t})
#   其中 R = ρ1（ell1）或 w_radius_abs（wass）

def build_aar_with_envelope2(envelope_type='ell1'):
    assert envelope_type in ('ell1','wass')
    R = rho1 if envelope_type == 'ell1' else w_radius_abs
    mdl = pl.LpProblem(f"AAR_{envelope_type}_lin", pl.LpMinimize)

    v_ = pl.LpVariable.dicts('v', list(range(1, K+1)), 0, 1, cat=pl.LpBinary)
    u0_ = pl.LpVariable.dicts('u0', list(range(1, K+1)), lowBound=0)
    A_ = {(k,t): pl.LpVariable(f"a_{k}_{t}", lowBound=None) for k in range(1,K+1) for t in range(1,k)}

    y0_ = pl.LpVariable.dicts('y0', list(range(1, K+1)), lowBound=0)
    Y_ = {(k,t): pl.LpVariable(f"Y_{k}_{t}", lowBound=None) for k in range(1,K+1) for t in range(1,k+1)}

    cumd = np.cumsum(d_hat)

    # u 鲁棒上下界（∥·∥_∞ 对偶）
    for k in range(1, K+1):
        if k == 1:
            mdl += u0_[1] >= 0
            mdl += u0_[1] <= M * v_[1]
        else:
            mU = pl.LpVariable(f"mU_{k}", lowBound=0)
            for t in range(1, k):
                mdl +=  mU >=  A_[(k,t)]
                mdl +=  mU >= -A_[(k,t)]
            env = R * mU
            mdl += u0_[k] - env >= 0
            mdl += u0_[k] + env <= M * v_[k]

    # y 包络（两侧，因果）
    for k in range(1, K+1):
        const_k = I1 + pl.lpSum(u0_[i] for i in range(1, k+1)) - cumd[k-1]
        # coeff_{k,t}
        coeff = {}
        for t in range(1, k+1):
            coeff[t] = pl.lpSum(A_[(i,t)] for i in range(max(t+1,2), k+1) if (i,t) in A_)
            if t == k:
                coeff[t] = coeff[t] + (-1)
        # y_const
        y_const = y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1, k+1))
        # 持有侧 env：mH ≥ ±(Y − h·coeff)
        mH = pl.LpVariable(f"mH_{k}", lowBound=0)
        for t in range(1, k+1):
            mdl += mH >=  (Y_[(k,t)] - h*coeff[t])
            mdl += mH >= -(Y_[(k,t)] - h*coeff[t])
        mdl += y_const >= h*const_k + R * mH
        # 缺货侧 env：mP ≥ ±(−p·coeff − Y)
        mP = pl.LpVariable(f"mP_{k}", lowBound=0)
        for t in range(1, k+1):
            mdl += mP >=  (-p*coeff[t] - Y_[(k,t)])
            mdl += mP >= -(-p*coeff[t] - Y_[(k,t)])
        mdl += y_const >= p*(-const_k) + R * mP

    # 目标中 z 部分（c*u 的 z 系数向量的 ∥·∥_∞ 对偶）：mG ≥ ±(c * ∑_{i>t} a_{i,t})
    mG = pl.LpVariable("mG", lowBound=0)
    for t in range(1, K+1):
        expr = c * pl.lpSum(A_[(i,t)] for i in range(max(t+1,2), K+1) if (i,t) in A_)
        mdl += mG >=  expr
        mdl += mG >= -expr

    W_ = pl.LpVariable('W', lowBound=0)
    mdl += W_ >= pl.lpSum(f*v_[k] + c*u0_[k] + (y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1,k+1))) for k in range(1, K+1)) \
                 + R * mG
    mdl.setObjective(W_)
    return mdl, dict(v=v_, u0=u0_, A=A_, y0=y0_, Y=Y_)

# %%
# 运行不同不确定集（统一因果/对偶；ell1/wass 使用 envelope2 线性近似）
models = {}
sol = {}

# box
mdl_box, vars_box = build_aar_with_envelope('box')
models['box'] = (mdl_box, vars_box)
status = mdl_box.solve(pl.PULP_CBC_CMD(msg=False, timeLimit=90))
sol['box'] = dict(status=pl.LpStatus[status], obj=float(pl.value(mdl_box.objective) or 0.0))

# poly（因果对偶）
mdl_poly, vars_poly = build_aar_with_envelope('poly')
models['poly'] = (mdl_poly, vars_poly)
status = mdl_poly.solve(pl.PULP_CBC_CMD(msg=False, timeLimit=90))
sol['poly'] = dict(status=pl.LpStatus[status], obj=float(pl.value(mdl_poly.objective) or 0.0))

# ell1（∞-范数对偶线性近似）
mdl_ell1, vars_ell1 = build_aar_with_envelope2('ell1')
models['ell1'] = (mdl_ell1, vars_ell1)
status = mdl_ell1.solve(pl.PULP_CBC_CMD(msg=False, timeLimit=90))
sol['ell1'] = dict(status=pl.LpStatus[status], obj=float(pl.value(mdl_ell1.objective) or 0.0))

# wass（∞-范数对偶线性近似）
mdl_wass, vars_wass = build_aar_with_envelope2('wass')
models['wass'] = (mdl_wass, vars_wass)
status = mdl_wass.solve(pl.PULP_CBC_CMD(msg=False, timeLimit=90))
sol['wass'] = dict(status=pl.LpStatus[status], obj=float(pl.value(mdl_wass.objective) or 0.0))

sol_df = pd.DataFrame([dict(uncertainty=name, status=info['status'], worst_obj=info['obj']) for name, info in sol.items()])
display(sol_df)

# %% [markdown]
# ## 使用 Gurobi 构建“精确”椭球集与 Wasserstein-1（L2地距离）鲁棒 AAR（SOCP/QCP）
# - 统一方法（Ben-Tal 风格）：将 max_{\|z\|_2≤ρ} 线性形式的最坏值替换为 ρ·\|coeff\|_2，并用二阶锥/二次约束表示。
# - 保持因果性：
#   - u_k(z) 仅含 z_1..z_{k-1}；鲁棒界：u0_k − ρ·\|a_{k,1..k−1}\|_2 ≥ 0，u0_k + ρ·\|a_{k,1..k−1}\|_2 ≤ M v_k。
#   - y_k(d) 单一且仿射：y_k(d)= y0_k + Σ_{t≤k} Y_{k,t} d_t；两侧包络分别用 ρ·\|Y−h·coeff\|_2 和 ρ·\|−p·coeff − Y\|_2。
# - Wasserstein-1（以 L2 为地距离）下，线性函数的最坏期望为 ϵ·\|coeff\|_2（精确），实现与椭球相同，仅将半径从 ρ 换为 ϵ。

# %%
# Gurobi 支持：构建 SOCP/QCP 版本的 AAR 椭球/Wasserstein
import math
try:
    import gurobipy as gp
    from gurobipy import GRB
    has_grb = True
except Exception:
    has_grb = False
print("Gurobi available:", has_grb)

rho = float(np.linalg.norm(delta, ord=2))  # 椭球半径（可调）
w_eps = 0.5 * rho                             # Wasserstein 半径（示例）


def build_aar_socp(radius, label="ell2"):
    # radius: L2 球半径（椭球或W1 epsilon）
    m = gp.Model(f"AAR_{label}")
    m.Params.OutputFlag = 0
    m.Params.NonConvex = 2  # 容忍非凸二次项（以防环境将 SOC 识别为非凸形式）

    v = m.addVars(range(1, K+1), vtype=GRB.BINARY, name='v')
    u0 = m.addVars(range(1, K+1), lb=0.0, name='u0')
    A = {(k,t): m.addVar(lb=-GRB.INFINITY, name=f"a_{k}_{t}") for k in range(1,K+1) for t in range(1,k)}

    y0 = m.addVars(range(1, K+1), lb=0.0, name='y0')
    Y = {(k,t): m.addVar(lb=-GRB.INFINITY, name=f"Y_{k}_{t}") for k in range(1,K+1) for t in range(1,k+1)}

    # 库存常数项
    cumd = np.cumsum(d_hat)

    # u 鲁棒上下界（SOCP）： ||a_{k,1..k-1}||_2 ≤ s_k, 然后 u0 ± radius*s_k 与 v 绑定
    s = m.addVars(range(1, K+1), lb=0.0, name='s')
    for k in range(1, K+1):
        if k == 1:
            m.addConstr(u0[1] >= 0)
            m.addConstr(u0[1] <= M * v[1])
        else:
            # ||a_{k,1..k-1}||_2 ≤ s_k
            expr = gp.quicksum(A[(k,t)]*A[(k,t)] for t in range(1,k))
            m.addQConstr(expr <= s[k]*s[k])
            m.addConstr(u0[k] - radius*s[k] >= 0)
            m.addConstr(u0[k] + radius*s[k] <= M * v[k])

    # y 包络（两侧）：
    # y_const = y0[k] + Σ Y_{k,t} d_hat_t
    # coeff_vec = [Σ_{i>t, i≤k} a_{i,t} − 1_{t=k}]_{t=1..k}
    # 约束： y_const ≥ h*(const_k) + radius * || Y_k - h*coeff_vec ||_2
    #        y_const ≥ p*(-const_k) + radius * || -p*coeff_vec - Y_k ||_2

    r1 = m.addVars(range(1, K+1), lb=0.0, name='r1')
    r2 = m.addVars(range(1, K+1), lb=0.0, name='r2')

    for k in range(1, K+1):
        const_k = I1 + gp.quicksum(u0[i] for i in range(1, k+1)) - float(cumd[k-1])
        # coeff_vec 构造二次范数
        # 定义辅助变量 W_{k,t} = Σ_{i>t, i≤k} a_{i,t} − 1_{t=k}
        W = {t: m.addVar(lb=-GRB.INFINITY, name=f"W_{k}{k}_{t}") for t in range(1, k+1)}
        for t in range(1, k+1):
            sum_at = gp.quicksum(A[(i,t)] for i in range(max(t+1,2), k+1) if (i,t) in A)
            m.addConstr(W[t] == sum_at + ( -1.0 if t == k else 0.0 ))
        # || Y_k - h*W ||_2 ≤ r1[k]
        m.addQConstr(gp.quicksum((Y[(k,t)] - h*W[t])*(Y[(k,t)] - h*W[t]) for t in range(1,k+1)) <= r1[k]*r1[k])
        # || -p*W - Y_k ||_2 ≤ r2[k]
        m.addQConstr(gp.quicksum((-p*W[t] - Y[(k,t)])*(-p*W[t] - Y[(k,t)]) for t in range(1,k+1)) <= r2[k]*r2[k])

        y_const = y0[k] + gp.quicksum(Y[(k,t)]*float(d_hat[t-1]) for t in range(1,k+1))
        m.addConstr(y_const >= h*const_k + radius * r1[k])
        m.addConstr(y_const >= p*(-const_k) + radius * r2[k])

    # 目标：W ≥ Σ (f v + c u0 + y_const) + radius * || [c*∑_{i>t} a_{i,t}]_{t=1..K} ||_2
    # 构造目标 z 系数向量 G_t = c * ∑_{i>t} a_{i,t}
    G = {t: m.addVar(lb=-GRB.INFINITY, name=f"G_{t}") for t in range(1, K+1)}
    for t in range(1, K+1):
        sum_at = gp.quicksum(A[(i,t)] for i in range(max(t+1,2), K+1) if (i,t) in A)
        m.addConstr(G[t] == c * sum_at)
    r_obj = m.addVar(lb=0.0, name='r_obj')
    m.addQConstr(gp.quicksum(G[t]*G[t] for t in range(1,K+1)) <= r_obj*r_obj)

    Wv = m.addVar(lb=0.0, name='W')
    m.addConstr(Wv >= gp.quicksum(f*v[k] + c*u0[k] + (y0[k] + gp.quicksum(Y[(k,t)]*float(d_hat[t-1]) for t in range(1,k+1))) for k in range(1, K+1)) \
                        + radius * r_obj)

    m.setObjective(Wv, GRB.MINIMIZE)
    return m

m_socp_ell = build_aar_socp(rho, label="ell2")
m_socp_wass = build_aar_socp(w_eps, label="wassL2")

def print_grb_obj(model, name):
    st = model.Status
    if st in (GRB.OPTIMAL, GRB.SUBOPTIMAL):
        try:
            print(f"{name} status={st}, obj={model.ObjVal}")
        except Exception:
            model.update()
            print(f"{name} status={st}, obj={model.getObjective().getValue()}")
    else:
        print(f"{name} status={st}, no objective value available")

if has_grb:
    m_socp_ell.optimize()
    m_socp_wass.optimize()
    print_grb_obj(m_socp_ell, 'ell2')
    print_grb_obj(m_socp_wass, 'wassL2')
else:
    print("Gurobi 不可用，跳过 SOCP 优化。")

# %% [markdown]
# ### 运行顺序建议
# 1. 参数/数据 → 名义/Box AAR/Static（线性）求解与指标查看
# 2. 扩展不确定集（poly/ell1/wass 线性版本对比）
# 3. 若 Gurobi 可用：运行“精确 ellipsoidal/Wasserstein-L2”单元，得到 SOCP/QC 目标
# 4. 可将 Gurobi 目标值追加到对比表，形成统一汇总

# %%
# 将 Gurobi 结果（若可用）加入对比表
try:
    _ = sol_df
except NameError:
    sol_df = pd.DataFrame()

if has_grb and 'm_socp_ell' in globals():
    def safe_obj(m):
        try:
            return m.ObjVal
        except Exception:
            m.update(); return m.getObjective().getValue()
    add_rows = []
    if m_socp_ell.Status in (GRB.OPTIMAL, GRB.SUBOPTIMAL):
        add_rows.append(dict(uncertainty='ell2_exact', status=int(m_socp_ell.Status), worst_obj=safe_obj(m_socp_ell)))
    if m_socp_wass.Status in (GRB.OPTIMAL, GRB.SUBOPTIMAL):
        add_rows.append(dict(uncertainty='wassL2_exact', status=int(m_socp_wass.Status), worst_obj=safe_obj(m_socp_wass)))
    if add_rows:
        sol_df = pd.concat([sol_df, pd.DataFrame(add_rows)], ignore_index=True)

def extract_grb_solution(m):
    # 提取 Gurobi 变量用于统一评估
    v_ = np.array([m.getVarByName(f"v[{k}]").X for k in range(1, K+1)])
    u0_ = np.array([m.getVarByName(f"u0[{k}]").X for k in range(1, K+1)])
    A_ = np.zeros((K,K))
    for k in range(1, K+1):
        for t in range(1, k):
            A_[k-1, t-1] = m.getVarByName(f"a_{k}_{t}").X
    return v_, u0_, A_

# 若可用，提取 ell2_exact / wassL2_exact 的解并并入 metrics
try:
    exact_rows = []
    if has_grb and m_socp_ell.Status in (GRB.OPTIMAL, GRB.SUBOPTIMAL):
        v_, u0_, A_ = extract_grb_solution(m_socp_ell)
        ev = evaluate(u0_, A_, v_, d_hat, delta, I1, costs_tuple, num_mc=200, seed=456)
        exact_rows.append(dict(method='ell2_exact', worst_obj=safe_obj(m_socp_ell), nominal_total=ev['nominal']['total'],
                               nominal_service=ev['nominal']['service_rate'], MC_mean_total=ev['mc']['total']['mean'],
                               MC_std_total=ev['mc']['total']['std'], MC_VaR95=ev['mc']['VaR95'], MC_CVaR95=ev['mc']['CVaR95'],
                               MC_mean_service=ev['mc']['service']['mean']))
    if has_grb and m_socp_wass.Status in (GRB.OPTIMAL, GRB.SUBOPTIMAL):
        v_, u0_, A_ = extract_grb_solution(m_socp_wass)
        ev = evaluate(u0_, A_, v_, d_hat, delta, I1, costs_tuple, num_mc=200, seed=789)
        exact_rows.append(dict(method='wassL2_exact', worst_obj=safe_obj(m_socp_wass), nominal_total=ev['nominal']['total'],
                               nominal_service=ev['nominal']['service_rate'], MC_mean_total=ev['mc']['total']['mean'],
                               MC_std_total=ev['mc']['total']['std'], MC_VaR95=ev['mc']['VaR95'], MC_CVaR95=ev['mc']['CVaR95'],
                               MC_mean_service=ev['mc']['service']['mean']))
    if exact_rows:
        metrics_df = pd.concat([metrics_df, pd.DataFrame(exact_rows)], ignore_index=True)
except Exception as e:
    print('extract Gurobi solution failed:', e)

sol_df

# %%
# 更丰富的对比：用各不确定集下的解，进行名义/随机/风险/服务指标评估

def extract_solution(vars_):
    v = np.array([pl.value(vars_['v'][k]) for k in range(1, K+1)])
    u0 = np.array([pl.value(vars_['u0'][k]) for k in range(1, K+1)])
    A = np.zeros((K,K))
    for k in range(1, K+1):
        for t in range(1, k):
            A[k-1,t-1] = pl.value(vars_['A'][(k,t)]) if (k,t) in vars_['A'] else 0.0
    return v, u0, A

all_metrics = []
for name, (mdl, vars_) in models.items():
    v_, u0_, A_ = extract_solution(vars_)
    ev = evaluate(u0_, A_, v_, d_hat, delta, I1, costs_tuple, num_mc=200, seed=123)
    all_metrics.append(dict(
        method=name,
        worst_obj=float(pl.value(mdl.objective) or 0.0),
        nominal_total=ev['nominal']['total'],
        nominal_service=ev['nominal']['service_rate'],
        MC_mean_total=ev['mc']['total']['mean'],
        MC_std_total=ev['mc']['total']['std'],
        MC_VaR95=ev['mc']['VaR95'],
        MC_CVaR95=ev['mc']['CVaR95'],
        MC_mean_service=ev['mc']['service']['mean'],
    ))
metrics_df = pd.DataFrame(all_metrics)
display(metrics_df.sort_values('worst_obj'))

# %%
# 修正版：统一对偶风格 + 因果结构的 ell1/wass 线性近似（基于 L1 集，对偶 ∥c∥_∞）
# - u 界：env = R * m_u，m_u ≥ ± a_{k,t}, t<k
# - y 包络：env = R * m_y，m_y ≥ ±(Y_{k,t} − h·coeff_{k,t}) 与 ±(−p·coeff_{k,t} − Y_{k,t})
#   其中 R = ρ1（ell1）或 w_radius_abs（wass）

def build_aar_with_envelope2(envelope_type='ell1'):
    assert envelope_type in ('ell1','wass')
    R = rho1 if envelope_type == 'ell1' else w_radius_abs
    mdl = pl.LpProblem(f"AAR_{envelope_type}_lin", pl.LpMinimize)

    v_ = pl.LpVariable.dicts('v', list(range(1, K+1)), 0, 1, cat=pl.LpBinary)
    u0_ = pl.LpVariable.dicts('u0', list(range(1, K+1)), lowBound=0)
    A_ = {(k,t): pl.LpVariable(f"a_{k}_{t}", lowBound=None) for k in range(1,K+1) for t in range(1,k)}

    y0_ = pl.LpVariable.dicts('y0', list(range(1, K+1)), lowBound=0)
    Y_ = {(k,t): pl.LpVariable(f"Y_{k}_{t}", lowBound=None) for k in range(1,K+1) for t in range(1,k+1)}

    cumd = np.cumsum(d_hat)

    # u 鲁棒上下界（∥·∥_∞ 对偶）
    for k in range(1, K+1):
        if k == 1:
            mdl += u0_[1] >= 0
            mdl += u0_[1] <= M * v_[1]
        else:
            mU = pl.LpVariable(f"mU_{k}", lowBound=0)
            for t in range(1, k):
                mdl +=  mU >=  A_[(k,t)]
                mdl +=  mU >= -A_[(k,t)]
            env = R * mU
            mdl += u0_[k] - env >= 0
            mdl += u0_[k] + env <= M * v_[k]

    # y 包络（两侧，因果）
    for k in range(1, K+1):
        const_k = I1 + pl.lpSum(u0_[i] for i in range(1, k+1)) - cumd[k-1]
        # coeff_{k,t}
        coeff = {}
        for t in range(1, k+1):
            coeff[t] = pl.lpSum(A_[(i,t)] for i in range(max(t+1,2), k+1) if (i,t) in A_)
            if t == k:
                coeff[t] = coeff[t] + (-1)
        # y_const
        y_const = y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1, k+1))
        # 持有侧 env：mH ≥ ±(Y − h·coeff)
        mH = pl.LpVariable(f"mH_{k}", lowBound=0)
        for t in range(1, k+1):
            mdl += mH >=  (Y_[(k,t)] - h*coeff[t])
            mdl += mH >= -(Y_[(k,t)] - h*coeff[t])
        mdl += y_const >= h*const_k + R * mH
        # 缺货侧 env：mP ≥ ±(−p·coeff − Y)
        mP = pl.LpVariable(f"mP_{k}", lowBound=0)
        for t in range(1, k+1):
            mdl += mP >=  (-p*coeff[t] - Y_[(k,t)])
            mdl += mP >= -(-p*coeff[t] - Y_[(k,t)])
        mdl += y_const >= p*(-const_k) + R * mP

    # 目标中 z 部分（c*u 的 z 系数向量的 ∥·∥_∞ 对偶）：mG ≥ ±(c * ∑_{i>t} a_{i,t})
    mG = pl.LpVariable("mG", lowBound=0)
    for t in range(1, K+1):
        expr = c * pl.lpSum(A_[(i,t)] for i in range(max(t+1,2), K+1) if (i,t) in A_)
        mdl += mG >=  expr
        mdl += mG >= -expr

    W_ = pl.LpVariable('W', lowBound=0)
    mdl += W_ >= pl.lpSum(f*v_[k] + c*u0_[k] + (y0_[k] + pl.lpSum(Y_[(k,t)]*d_hat[t-1] for t in range(1,k+1))) for k in range(1, K+1)) \
                 + R * mG
    mdl.setObjective(W_)
    return mdl, dict(v=v_, u0=u0_, A=A_, y0=y0_, Y=Y_)

# %% [markdown]
# ### 说明与排查
# - 如 ell1 与 box/wass 出现近似相同或为 0，请检查：
#   - ell1 与 wass 是否已切换为 build_aar_with_envelope2（∞-范数对偶）的实现；
#   - 变动成本 c=0 会使目标的“u 仿射 z 部分”项消失；此时差异主要来自 y 的包络，若 R（ρ1 或 ε）设得很小，也会导致数值相近。
# - Gurobi 状态 3 表示不可行/未得到目标值：缩小 ρ 或 ε，再优化；或打开日志（OutputFlag=1）定位冲突约束。

# %%
# 指标对齐：为每个不确定集补充 worst_plus_total / worst_minus_total / historical_total

rows = []
for name, (mdl, vars_) in models.items():
    v_, u0_, A_ = extract_solution(vars_)
    # 名义/MC 已有；此处补 worst_plus/minus 与 historical
    plus = simulate_trajectory(affine_policy_orders(u0_, A_, +delta), v_, d_hat, +delta, I1, costs_tuple)
    minus = simulate_trajectory(affine_policy_orders(u0_, A_, -delta), v_, d_hat, -delta, I1, costs_tuple)

    hist_total = None
    if 'demand' in forecast_df.columns:
        d_real = forecast_df.groupby('period', as_index=False)['demand'].sum().head(K)['demand'].to_numpy()
        z_hist = d_real - d_hat
        hist = simulate_trajectory(affine_policy_orders(u0_, A_, z_hist), v_, d_hat, z_hist, I1, costs_tuple)
        hist_total = hist['total']

    rows.append(dict(method=name,
                     worst_obj=float(pl.value(mdl.objective) or 0.0),
                     nominal_total=simulate_trajectory(affine_policy_orders(u0_, A_, np.zeros_like(delta)), v_, d_hat, np.zeros_like(delta), I1, costs_tuple)['total'],
                     worst_plus_total=plus['total'],
                     worst_minus_total=minus['total'],
                     historical_total=hist_total))

aligned_df = pd.DataFrame(rows)
display(aligned_df)

# %%
# AAR/Static summary 对齐：补 worst_obj 与 historical_total
worst_obj_aar = float(pl.value(W) or 0.0)
worst_obj_sta = float(pl.value(W_s) or 0.0)

hist_rows = []
if 'demand' in forecast_df.columns:
    d_real = forecast_df.groupby('period', as_index=False)['demand'].sum().head(K)['demand'].to_numpy()
    z_hist = d_real - d_hat
    aar_hist = simulate_trajectory(affine_policy_orders(u0_sol, A_mat, z_hist), v_sol, d_hat, z_hist, I1, costs_tuple)
    sta_hist = simulate_trajectory(affine_policy_orders(us_sol, None, z_hist), vs_sol, d_hat, z_hist, I1, costs_tuple)
    hist_rows = [aar_hist['total'], sta_hist['total']]
else:
    hist_rows = [None, None]

summary_aligned = pd.DataFrame([
    dict(method='AAR', worst_obj=worst_obj_aar, historical_total=hist_rows[0],
         nominal_total=aar_eval['nominal']['total'], nominal_service=aar_eval['nominal']['service_rate'],
         MC_mean_total=aar_eval['mc']['total']['mean'], MC_std_total=aar_eval['mc']['total']['std'],
         MC_VaR95=aar_eval['mc']['VaR95'], MC_CVaR95=aar_eval['mc']['CVaR95'], MC_mean_service=aar_eval['mc']['service']['mean']),
    dict(method='Static', worst_obj=worst_obj_sta, historical_total=hist_rows[1],
         nominal_total=sta_eval['nominal']['total'], nominal_service=sta_eval['nominal']['service_rate'],
         MC_mean_total=sta_eval['mc']['total']['mean'], MC_std_total=sta_eval['mc']['total']['std'],
         MC_VaR95=sta_eval['mc']['VaR95'], MC_CVaR95=sta_eval['mc']['CVaR95'], MC_mean_service=sta_eval['mc']['service']['mean'])
])
display(summary_aligned)

# %%
# 解释为什么 worst_obj 与 nominal 可能相等：当前 c=0，且 y 的鲁棒包络在对称 Box 下，
# 当最优策略使 I_k 在名义下紧贴 0 且对称偏差的最坏值通过包络被同一 y_const 覆盖时，会出现相等。
# 为验证差异，尝试：提高 p 或 h，或将 delta_ratio 增大，或设置 c>0，以拉开最坏与名义。

print('当前参数: c=', c, ' h=', h, ' p=', p, ' delta_ratio=', delta_ratio)

# %%
# 让 Gurobi 更容易可行的建议与快速试跑（可调参数）
# 1) 减小半径：
rho_try = 0.3 * float(np.linalg.norm(delta, ord=2))
w_eps_try = 0.3 * rho_try
# 2) 放宽固定费或增大缺货罚：
f_try = max(1.0, f/5)
p_try = max(p, 10.0)

if has_grb:
    m_try = build_aar_socp(rho_try, label="ell2_try")
    m_try.optimize()
    print_grb_obj(m_try, 'ell2_try')
else:
    print('Gurobi 不可用，跳过试跑。')

# %%
# 统一汇总：AAR/Static 与各不确定集的一致指标，并可视化多方法分布

# 辅助：从 pulp 变量字典提取解

def _extract_solution_from_vars(vars_dict):
    v = np.array([pl.value(vars_dict['v'][k]) for k in range(1, K+1)])
    u0 = np.array([pl.value(vars_dict['u0'][k]) for k in range(1, K+1)])
    A = np.zeros((K, K))
    for k in range(1, K+1):
        for t in range(1, k):
            A[k-1, t-1] = pl.value(vars_dict['A'][(k, t)]) if (k, t) in vars_dict['A'] else 0.0
    return v, u0, A

# 组装需要评估的方法
methods = []
# AAR 与 Static（基线 Box）
methods.append(dict(name='AAR', v=v_sol, u0=u0_sol, A=A_mat, worst_obj=float(pl.value(W) or 0.0)))
methods.append(dict(name='Static', v=vs_sol, u0=us_sol, A=None, worst_obj=float(pl.value(W_s) or 0.0)))

# 其它不确定集（poly/ell1/wass）
for mname, (mdl, vdict) in models.items():
    v_, u0_, A_ = _extract_solution_from_vars(vdict)
    methods.append(dict(name=mname, v=v_, u0=u0_, A=A_, worst_obj=float(pl.value(mdl.objective) or 0.0)))

# 若有 Gurobi 精确模型，追加（若优化状态可用）
try:
    if has_grb:
        def _safe_obj(m):
            try:
                return float(m.ObjVal)
            except Exception:
                m.update(); return float(m.getObjective().getValue())
        def _extract_grb(m):
            v_ = np.array([m.getVarByName(f"v[{k}]").X for k in range(1, K+1)])
            u0_ = np.array([m.getVarByName(f"u0[{k}]").X for k in range(1, K+1)])
            A_ = np.zeros((K, K))
            for k in range(1, K+1):
                for t in range(1, k):
                    A_[k-1, t-1] = m.getVarByName(f"a_{k}_{t}").X
            return v_, u0_, A_
        if 'm_socp_ell' in globals() and m_socp_ell.Status in (gp.GRB.OPTIMAL, gp.GRB.SUBOPTIMAL):
            v_, u0_, A_ = _extract_grb(m_socp_ell)
            methods.append(dict(name='ell2_exact', v=v_, u0=u0_, A=A_, worst_obj=_safe_obj(m_socp_ell)))
        if 'm_socp_wass' in globals() and m_socp_wass.Status in (gp.GRB.OPTIMAL, gp.GRB.SUBOPTIMAL):
            v_, u0_, A_ = _extract_grb(m_socp_wass)
            methods.append(dict(name='wassL2_exact', v=v_, u0=u0_, A=A_, worst_obj=_safe_obj(m_socp_wass)))
except Exception as _e:
    print('Skip exact models:', _e)

# 历史真实需求（若可用）
has_hist = 'demand' in forecast_df.columns
if has_hist:
    agg_real = forecast_df.groupby('period', as_index=False)['demand'].sum().head(K)
    d_real = agg_real['demand'].to_numpy()
    z_hist = d_real - d_hat

rows = []
for m in methods:
    v_, u0_, A_ = m['v'], m['u0'], m['A']
    ev = evaluate(u0_, A_, v_, d_hat, delta, I1, costs_tuple, num_mc=300, seed=24601)
    # 最坏正负偏差
    plus = simulate_trajectory(affine_policy_orders(u0_, A_, +delta), v_, d_hat, +delta, I1, costs_tuple)
    minus = simulate_trajectory(affine_policy_orders(u0_, A_, -delta), v_, d_hat, -delta, I1, costs_tuple)
    # 历史指标
    hist_total = None; hist_service = None; hist_stockouts = None
    if has_hist:
        hist = simulate_trajectory(affine_policy_orders(u0_, A_, z_hist), v_, d_hat, z_hist, I1, costs_tuple)
        hist_total, hist_service, hist_stockouts = hist['total'], hist['service_rate'], hist['stockouts']
    rows.append(dict(
        method=m['name'],
        worst_obj=float(m['worst_obj']),
        nominal_total=float(ev['nominal']['total']),
        nominal_service=float(ev['nominal']['service_rate']),
        worst_plus_total=float(plus['total']),
        worst_minus_total=float(minus['total']),
        MC_mean_total=float(ev['mc']['total']['mean']),
        MC_std_total=float(ev['mc']['total']['std']),
        MC_VaR95=float(ev['mc']['VaR95']),
        MC_CVaR95=float(ev['mc']['CVaR95']),
        MC_mean_service=float(ev['mc']['service']['mean']),
        historical_total=(None if hist_total is None else float(hist_total)),
        historical_service=(None if hist_service is None else float(hist_service)),
        historical_stockouts=(None if hist_stockouts is None else int(hist_stockouts)),
    ))

final_summary = pd.DataFrame(rows)
display(final_summary.sort_values(['method']).reset_index(drop=True))

# 多方法随机场景总成本分布对比
rng = np.random.default_rng(13579)
N = 400
long_records = []
for m in methods:
    v_, u0_, A_ = m['v'], m['u0'], m['A']
    totals = []
    for _ in range(N):
        z = rng.uniform(low=-delta, high=+delta)
        tot = simulate_trajectory(affine_policy_orders(u0_, A_, z), v_, d_hat, z, I1, costs_tuple)['total']
        totals.append(tot)
        long_records.append(dict(method=m['name'], total=float(tot)))

plot_df = pd.DataFrame(long_records)
plt.figure(figsize=(11, 6))
for name, sub in plot_df.groupby('method'):
    plt.hist(sub['total'], bins=24, alpha=0.35, density=True, label=f"{name}")
    plt.axvline(sub['total'].mean(), linestyle='--', linewidth=1)
plt.title('随机场景总成本分布对比（AAR/Static/多不确定集）')
plt.xlabel('Total cost')
plt.ylabel('Density')
plt.legend()
plt.show()
